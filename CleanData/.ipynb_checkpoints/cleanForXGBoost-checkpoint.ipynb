# %%
import pandas as pd
ORIGINAL_DATA_FILE ='[new] yancheng_train_20171226_2.csv'
df = pd.read_csv('../RawData/'+ORIGINAL_DATA_FILE)
classList = df['class_id'].unique()

mutipleValueList = set()
for columnName in df.columns:
    for classId in classList:
        tempDf = df[df['class_id']==classId]
        if len(tempDf[columnName].unique())>1:
            mutipleValueList.add(columnName)
columnsList = list(df.columns)
for mutipleValueColumn in mutipleValueList:
    columnsList.remove(mutipleValueColumn)
# columnsList.append('sale_date')
columnsList = columnsList + ['sale_date', 'price_level']
resultDf = df.groupby(columnsList)['sale_quantity'].sum().to_frame()
resultDf.reset_index(level=columnsList, inplace=True)
def handleSaleDate(df):
    # split date to month and year
    def operateDateToYear(x):
        return x[:4]
    def operateDateToMonth(x):
        return x[4:]
    df['sale_date'] = df['sale_date'].astype('str')
    df['year'] = df['sale_date'].apply(operateDateToYear)
    df['month'] = df['sale_date'].apply(operateDateToMonth)
    df = df.drop(['sale_date'], axis=1)
    return df
resultDf = handleSaleDate(resultDf)
def mapPriceLevel(x):
    arr = x.split('-')
    if len(arr) < 2:
        return float(arr[0].split('W')[0])/2
    else:
        subArr = arr[1].split('W')
        return (float(arr[0]) + float(subArr[0]))/2
resultDf['price_level'] = resultDf['price_level'].apply(mapPriceLevel)
def mapRatedPassenger(x):
    monthMap = {'Jul':6,'May':5,'Aug':8}
    if '-' in x:
        arr = x.split('-')
        if arr[1] in monthMap.keys():
            arr[1] = monthMap.get(arr[1])
#             print(arr[1], 'in monthMap')
        return (float(arr[0]) + float(arr[1]))/2
    else:
        return float(x)
# resultDf['rated_passenger'] = resultDf['rated_passenger'].apply(mapRatedPassenger)

# resultDf = resultDf.drop('brand_id', axis=1)
resultDf = pd.get_dummies(resultDf, columns=['class_id', 
                                             'brand_id', 
                                             'department_id','year', 'month'])
# Out:
# c:\ricy\python\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pandas as pd
from sklearn.preprocessing import normalize
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt
import re
# %matplotlib inline

resultDf = resultDf.sample(frac=1).reset_index(drop=True)

inputX = resultDf.drop('sale_quantity', axis=1)
inputY = resultDf['sale_quantity']
# inputY = resultArray.reshape((len(resultArray),1))
# train_x, test_x, train_y, test_y = train_test_split(inputX, inputY, test_size=0.2, random_state=42)
data_train, data_test, label_train, label_test = train_test_split(inputX, inputY, test_size = 0.2, random_state = 42)

dtrain = xgb.DMatrix(data_train, label_train)
dtest = xgb.DMatrix(data_test)

learningRateList = [0.1, 0.2, 0.3, 0.01, 0.03, 0.05]
maxDepthList = [5, 6, 7, 8, 9, 10]

testScore = 10000
trainScore = 10000
finalLearningRate = 0
finalMaxDepth = 0
model = 0
for learingRate in learningRateList:
    for maxDepth in maxDepthList:
        xgb_params = {
            'max_depth': maxDepth,
            'learning_rate': learingRate,
            'subsample': 0.5,
            'colsample_bytree': 0.7,
            'objective': 'reg:linear',
            'booster':'gbtree',
            'eval_metric': 'rmse',
            'silent': True,
            'gamma': 5,
            'n_estimators': 100
        }
        num_round = 200
        model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round= num_round)
        train_rmse = rmse(label_train.values, model.predict(dtrain, ntree_limit=num_round))
        test_rmse = rmse(label_test.values, model.predict(dtest, ntree_limit=num_round))
        if test_rmse<testScore:
            trainScore = train_rmse
            testScore = test_rmse
            finalLearningRate = learingRate
            finalMaxDepth = maxDepth
print("learningRate: {} and maxDepth: {} and train error: {} and test error : {}".format(finalLearningRate, finalMaxDepth,
                                                                                         trainScore, testScore))
fig, ax = plt.subplots(1, 1, figsize=(12, 50))
xgb.plot_importance(model, max_num_features=100, height=0.5, ax=ax)
# Out:
# learningRate: 0.2 and maxDepth: 9 and train error: 82.52253646351473 and test error : 230.15366988924856

# %%
df['brand_id'].unique()
# Out:
# array([750, 236, 638, 872, 304, 106, 761, 831, 537, 637,  75, 814,  12,
#         98, 807, 450, 953, 985, 864, 692, 836, 290, 783, 497, 813, 923,
#        512, 498, 841, 542, 294,  49, 126,  68, 682,  76], dtype=int64)

# %%
columnNameList = [x for x in list(df.columns) if x not in ['sale_date', 'class_id', 'sale_quantity', 'price']]
for columnName in columnNameList:
    for classId in classList:
        tempDf = df[df['class_id']==classId]
        if len(tempDf[columnName].unique())>1 and columnName != '':
            print(classId, ' ', columnName, ' ', tempDf[columnName].unique())
# Out:
# 745137   compartment   [3 2]
# 978089   compartment   [2 3]
# 349023   compartment   [3 2]
# 281792   compartment   [2 3]
# 289386   compartment   [3 2]
# 914348   compartment   [2 3]
# 248352   compartment   [3 2]
# 687270   type_id   [3 2]
# 687270   level_id   ['3' '1']
# 175962   TR   ['5' '6']
# 961962   TR   ['5' '6' '7']
# 409854   TR   ['6' '7' '5' '4']
# 437598   TR   ['6' '7']
# 603972   TR   ['0' '7' '6']
# 576298   TR   ['5' '6']
# 304458   TR   ['0' '5' '6' '4']
# 384924   TR   ['0' '6' '7']
# 591790   TR   ['0' '5' '6']
# 136916   TR   ['0' '6' '4' '5']
# 597927   TR   ['6' '7']
# 468392   TR   ['0' '5' '6']
# 356986   TR   ['0' '6']
# 851857   TR   ['9' '8']
# 290854   TR   ['0' '5' '6']
# 732758   TR   ['6' '8']
# 745137   TR   ['6' '5']
# 714860   TR   ['6' '7']
# 692703   TR   ['5' '7' '6']
# 978089   TR   ['5' '0' '6']
# 349023   TR   ['5' '6' '7']
# 281792   TR   ['7' '5']
# 379876   TR   ['6' '4' '5']
# 750340   TR   ['6' '5']
# 347384   TR   ['6' '7']
# 354068   TR   ['0' '5' '4' '6']
# 416749   TR   ['0' '6']
# 281301   TR   ['7' '5' '6']
# 654134   TR   ['5' '6']
# 425432   TR   ['6' '7' '5']
# 819061   TR   ['6' '5']
# 482497   TR   ['8' '8;7']
# 614059   TR   ['7' '9' '5']
# 527809   TR   ['9' '7' '5']
# 472603   TR   ['5' '6' '4' '5;4']
# 291514   TR   ['4' '5']
# 649213   TR   ['8' '6']
# 854079   TR   ['5' '0']
# 453752   TR   ['8' '6']
# 587678   TR   ['0' '6']
# 924154   TR   ['5' '6']
# 628041   TR   ['7' '5' '6']
# 378356   TR   ['0' '5']
# 245609   TR   ['6' '5' '7']
# 103507   TR   ['6' '7']
# 412240   TR   ['5' '6']
# 350259   TR   ['7' '5']
# 713651   TR   ['0' '6' '5']
# 671482   TR   ['5' '6']
# 221795   TR   ['7' '6']
# 492952   TR   ['0' '5']
# 580634   TR   ['0' '5' '6']
# 496459   TR   ['5' '0']
# 321683   TR   ['7' '5' '6']
# 714152   TR   ['6' '7']
# 735971   TR   ['7' '5' '6']
# 739296   TR   ['5' '6']
# 392593   TR   ['0' '6']
# 580470   TR   ['7' '5' '6']
# 741152   TR   ['7' '6']
# 682651   TR   ['7' '0' '6']
# 526401   TR   ['7' '6']
# 379265   TR   ['5' '6']
# 291086   TR   ['6' '9']
# 651347   TR   ['0' '5']
# 743957   TR   ['5' '6']
# 914348   TR   ['6' '5' '7']
# 883691   TR   ['7' '6']
# 436105   TR   ['7' '6']
# 248352   TR   ['4' '5' '6']
# 961362   TR   ['0' '5' '6']
# 950264   TR   ['6' '7']
# 308913   TR   ['7' '6' '5']
# 250658   TR   ['7' '6']
# 621073   TR   ['5' '4']
# 198427   TR   ['5' '4' '6']
# 619401   TR   ['5' '0']
# 348641   TR   ['4' '5' '7']
# 194450   TR   ['7' '6' '4' '5']
# 206765   TR   ['7' '6']
# 953842   TR   ['6' '7']
# 395234   TR   ['5' '6' '5;4']
# 302513   TR   ['5' '0' '6']
# 973106   TR   ['9' '0']
# 683364   TR   ['6' '0']
# 360648   TR   ['0' '5' '4']
# 569154   TR   ['6' '7']
# 810398   TR   ['6' '5' '7']
# 475895   TR   ['6' '5' '7']
# 890189   TR   ['6' '5']
# 815230   TR   ['7' '9']
# 861459   TR   ['6' '7']
# 437063   TR   ['6' '8']
# 854548   TR   ['6' '4' '5']
# 789290   TR   ['5' '0']
# 417803   TR   ['0' '5']
# 714150   TR   ['6' '9']
# 905061   TR   ['6' '5']
# 725137   TR   ['6' '5']
# 175962   gearbox_type   ['MT' 'AT']
# 961962   gearbox_type   ['MT' 'AT' 'DCT']
# 409854   gearbox_type   ['MT' 'AT' 'DCT']
# 437598   gearbox_type   ['MT' 'AT' 'DCT']
# 603972   gearbox_type   ['CVT' 'DCT' 'MT' 'AT']
# 304458   gearbox_type   ['CVT' 'MT' 'AT']
# 384924   gearbox_type   ['CVT' 'AT' 'DCT']
# 591790   gearbox_type   ['CVT' 'MT']
# 136916   gearbox_type   ['CVT' 'AT']
# 597927   gearbox_type   ['AT' 'DCT' 'MT']
# 468392   gearbox_type   ['CVT' 'AT' 'MT']
# 356986   gearbox_type   ['CVT' 'AT']
# 290854   gearbox_type   ['CVT' 'AT' 'MT']
# 732758   gearbox_type   ['AT' 'MT']
# 289403   gearbox_type   ['MT' 'DCT']
# 745137   gearbox_type   ['DCT' 'AT' 'MT']
# 714860   gearbox_type   ['AT' 'DCT' 'MT']
# 692703   gearbox_type   ['MT' 'DCT' 'AT']
# 978089   gearbox_type   ['MT' 'CVT']
# 219195   gearbox_type   ['AT' 'MT']
# 349023   gearbox_type   ['MT' 'AT' 'DCT']
# 281792   gearbox_type   ['DCT' 'MT']
# 379876   gearbox_type   ['AT' 'MT']
# 750340   gearbox_type   ['MT' 'AT']
# 347384   gearbox_type   ['AT' 'MT' 'DCT']
# 354068   gearbox_type   ['CVT' 'MT' 'AT']
# 416749   gearbox_type   ['CVT' 'MT']
# 786351   gearbox_type   ['MT' 'AT']
# 281301   gearbox_type   ['DCT' 'MT' 'AT']
# 654134   gearbox_type   ['AMT' 'MT' 'DCT']
# 425432   gearbox_type   ['AT' 'DCT' 'MT']
# 819061   gearbox_type   ['MT' 'AT']
# 482497   gearbox_type   ['AT' 'AT;DCT']
# 472603   gearbox_type   ['MT' 'AT' 'MT;AT']
# 124140   gearbox_type   ['AT' 'MT']
# 291514   gearbox_type   ['AT' 'MT']
# 693436   gearbox_type   ['DCT' 'MT']
# 854079   gearbox_type   ['MT' 'CVT' 'AT']
# 453752   gearbox_type   ['AT' 'MT']
# 587678   gearbox_type   ['CVT' 'MT']
# 924154   gearbox_type   ['MT' 'AT']
# 628041   gearbox_type   ['DCT' 'MT' 'AT']
# 378356   gearbox_type   ['CVT' 'MT']
# 245609   gearbox_type   ['AT' 'MT' 'DCT']
# 905745   gearbox_type   ['MT' 'AT']
# 540712   gearbox_type   ['AT' 'MT']
# 103507   gearbox_type   ['MT' 'AT' 'DCT']
# 412240   gearbox_type   ['MT' 'AT']
# 350259   gearbox_type   ['DCT' 'MT']
# 713651   gearbox_type   ['CVT' 'MT' 'AT']
# 671482   gearbox_type   ['MT' 'DCT' 'AT']
# 492952   gearbox_type   ['CVT' 'MT']
# 580634   gearbox_type   ['CVT' 'MT']
# 496459   gearbox_type   ['MT' 'CVT']
# 321683   gearbox_type   ['DCT' 'MT' 'AT']
# 714152   gearbox_type   ['AT' 'MT' 'DCT']
# 735971   gearbox_type   ['DCT' 'MT' 'AT']
# 739296   gearbox_type   ['MT' 'AMT']
# 289386   gearbox_type   ['AT' 'MT']
# 392593   gearbox_type   ['CVT' 'MT' 'DCT']
# 963845   gearbox_type   ['MT' 'AT']
# 580470   gearbox_type   ['DCT' 'MT' 'AT']
# 741152   gearbox_type   ['DCT' 'AT']
# 682651   gearbox_type   ['DCT' 'CVT' 'MT']
# 526401   gearbox_type   ['DCT' 'MT' 'AT']
# 379265   gearbox_type   ['MT' 'AMT']
# 291086   gearbox_type   ['AT' 'MT']
# 651347   gearbox_type   ['CVT' 'MT' 'AT']
# 743957   gearbox_type   ['MT' 'AT']
# 914348   gearbox_type   ['AT' 'MT' 'DCT']
# 923841   gearbox_type   ['AT' 'MT']
# 436105   gearbox_type   ['DCT' 'AT' 'MT']
# 481950   gearbox_type   ['AT' 'MT']
# 248352   gearbox_type   ['AT' 'MT']
# 961362   gearbox_type   ['CVT' 'MT']
# 950264   gearbox_type   ['DCT' 'MT']
# 308913   gearbox_type   ['DCT' 'AT' 'MT']
# 250658   gearbox_type   ['DCT' 'AT']
# 621073   gearbox_type   ['MT' 'AT']
# 198427   gearbox_type   ['MT' 'AT']
# 619401   gearbox_type   ['MT' 'CVT']
# 348641   gearbox_type   ['AT' 'MT' 'DCT']
# 194450   gearbox_type   ['DCT' 'AT' 'MT']
# 206765   gearbox_type   ['DCT' 'MT' 'AT']
# 953842   gearbox_type   ['AT' 'DCT' 'MT']
# 395234   gearbox_type   ['MT' 'AT' 'MT;AT']
# 302513   gearbox_type   ['MT' 'CVT']
# 973106   gearbox_type   ['AT' 'CVT']
# 683364   gearbox_type   ['MT' 'CVT']
# 360648   gearbox_type   ['CVT' 'MT' 'AT']
# 569154   gearbox_type   ['MT' 'DCT']
# 810398   gearbox_type   ['AT' 'MT' 'DCT']
# 475895   gearbox_type   ['AT' 'MT' 'DCT']
# 890189   gearbox_type   ['MT' 'AMT']
# 815230   gearbox_type   ['DCT' 'AT']
# 861459   gearbox_type   ['MT' 'DCT']
# 854548   gearbox_type   ['AT' 'MT']
# 789290   gearbox_type   ['MT' 'CVT']
# 417803   gearbox_type   ['CVT' 'MT']
# 612523   gearbox_type   ['MT' 'AT']
# 725137   gearbox_type   ['AT' 'MT']
# 340175   gearbox_type   ['MT' 'AT']
# 175962   displacement   [ 1.6  1.4]
# 961962   displacement   [ 1.6  1.4  1.5]
# 409854   displacement   [ 2.   1.5  1.3  2.4]
# 437598   displacement   [ 2.   1.5]
# 603972   displacement   [ 2.7  3.   1.8  2.5  2.   2.8  3.1  2.4]
# 576298   displacement   [ 1.9  1.6  2.   1.5  2.4]
# 304458   displacement   [ 1.8  1.6  1.2]
# 384924   displacement   [ 1.8  2.4  1.5  2.   3. ]
# 591790   displacement   [ 1.8  1.6  1.2]
# 136916   displacement   [ 2.5  2.4  2. ]
# 597927   displacement   [ 2.   1.6  2.4]
# 468392   displacement   [ 2.   2.4  3. ]
# 356986   displacement   [ 2.   1.5]
# 290854   displacement   [ 2.   2.4  1.5]
# 732758   displacement   [ 1.5  2. ]
# 289403   displacement   [ 1.8  1.3]
# 745137   displacement   [ 1.6  1.5  1.   2. ]
# 714860   displacement   [ 1.8  2.   1.6]
# 270690   displacement   [ 1.5  1.2]
# 692703   displacement   [ 1.3  1.5]
# 978089   displacement   [ 1.5  1.3]
# 349023   displacement   [ 1.5  1.6  1.4  1.8]
# 281792   displacement   [ 1.8  1.4  2. ]
# 379876   displacement   [ 1.2  1.6  2. ]
# 347384   displacement   [ 1.6  1.4  1.8]
# 354068   displacement   [ 1.6  1.8  2. ]
# 416749   displacement   [ 1.5  1.8]
# 125403   displacement   [ 3.   2.4  2.   2.5]
# 786351   displacement   [ 1.6  1.8]
# 281301   displacement   [ 2.   1.4  1.8  3. ]
# 654134   displacement   [ 1.8  1.5]
# 425432   displacement   [ 1.6  1.4  2.   1.2]
# 871642   displacement   [ 1.5  2.   1.6]
# 559132   displacement   [ 2.5  2. ]
# 819061   displacement   [ 2.   2.4]
# 614059   displacement   [ 2.   1.6  1.8  3. ]
# 527809   displacement   [ 2.   3.   1.8]
# 472603   displacement   [ 1.8  1.6  1.2  2. ]
# 124140   displacement   [ 1.8  2.   1.5]
# 693436   displacement   [ 1.3  1.8]
# 453752   displacement   [ 2.   1.5  1.6  2.5]
# 587678   displacement   [ 1.8  1.5]
# 628041   displacement   [ 1.4  1.6  2.   1.2]
# 209945   displacement   [ 2.   3.   2.5]
# 245609   displacement   [ 1.6  1.4]
# 540712   displacement   [ 1.8  2. ]
# 265980   displacement   [ 1.3  1.5]
# 103507   displacement   [ 1.6  2. ]
# 412240   displacement   [ 1.6  1.5]
# 350259   displacement   [ 1.4  2.   1.8]
# 713651   displacement   [ 1.5  1.   1.8  2. ]
# 671482   displacement   [ 1.   1.5]
# 221795   displacement   [ 2.   1.4]
# 321683   displacement   [ 1.4  1.6  1.2  2.   1.8]
# 714152   displacement   [ 1.8  2.   1.4]
# 735971   displacement   [ 1.4  1.5  1.   1.6  1.8]
# 739296   displacement   [ 1.5  1.8]
# 289386   displacement   [ 2.   1.5]
# 392593   displacement   [ 2.   1.5]
# 963845   displacement   [ 1.6  2. ]
# 580470   displacement   [ 1.4  1.6  1.5]
# 741152   displacement   [ 1.5  2. ]
# 682651   displacement   [ 2.   1.8]
# 401052   displacement   [ 2.   1.6]
# 526401   displacement   [ 1.4  1.6]
# 379265   displacement   [ 1.2  1.5]
# 560265   displacement   [ 1.5  1.2]
# 291086   displacement   [ 2.   1.6  1.5  2.4]
# 651347   displacement   [ 1.5  1.3]
# 914348   displacement   [ 1.6  1.4]
# 883691   displacement   [ 1.8  1.4  2.   3. ]
# 923841   displacement   [ 1.5  1.6  2.   2.4]
# 436105   displacement   [ 1.6  1.8  2. ]
# 481950   displacement   [ 2.5  2. ]
# 248352   displacement   [ 1.4  1.6]
# 961362   displacement   [ 2.   1.2  1.6]
# 950264   displacement   [ 2.   1.5]
# 308913   displacement   [ 1.4  1.6  1.2]
# 250658   displacement   [ 1.5  2.5]
# 621073   displacement   [ 1.2  1.5]
# 198427   displacement   [ 1.5  1.3]
# 651782   displacement   [ 2.   3.6]
# 619401   displacement   [ 1.8  1.3]
# 348641   displacement   [ 1.5  1.4]
# 194450   displacement   [ 1.6  2. ]
# 178529   displacement   [ 1.2  1.   1.1]
# 953842   displacement   [ 2.   1.6]
# 395234   displacement   [ 2.   1.8  1.6  2.3]
# 973106   displacement   [ 2.   1.5]
# 760412   displacement   [ 2.4  2. ]
# 360648   displacement   [ 1.5  1.3]
# 378536   displacement   [ 1.8  1.6]
# 810398   displacement   [ 1.6  1.4]
# 475895   displacement   [ 1.6  1.4]
# 249875   displacement   [ 2.5  2. ]
# 815230   displacement   [ 1.4  2.4]
# 861459   displacement   [ 1.5  1. ]
# 437063   displacement   [ 1.5  2. ]
# 854548   displacement   [ 1.   1.5]
# 789290   displacement   [ 1.5  1.3]
# 714150   displacement   [ 1.5  2. ]
# 687270   displacement   [ 1.5  1.2]
# 905061   displacement   [ 1.5  1.6]
# 725137   displacement   [ 1.3  1.5]
# 961962   if_charging   ['L' 'T']
# 409854   if_charging   ['T' 'L']
# 603972   if_charging   ['T' 'L']
# 576298   if_charging   ['T' 'L']
# 304458   if_charging   ['L' 'T']
# 384924   if_charging   ['L' 'T']
# 591790   if_charging   ['L' 'T']
# 597927   if_charging   ['L' 'T']
# 356986   if_charging   ['L' 'T']
# 290854   if_charging   ['L' 'T']
# 732758   if_charging   ['T' 'L']
# 289403   if_charging   ['L' 'T']
# 745137   if_charging   ['L' 'T']
# 714860   if_charging   ['L' 'T']
# 978089   if_charging   ['L' 'T']
# 349023   if_charging   ['L' 'T']
# 379876   if_charging   ['T' 'L']
# 347384   if_charging   ['L' 'T']
# 125403   if_charging   ['L' 'T']
# 281301   if_charging   ['T' 'L']
# 654134   if_charging   ['L' 'T']
# 425432   if_charging   ['L' 'T']
# 614059   if_charging   ['T' 'L']
# 527809   if_charging   ['T' 'L']
# 472603   if_charging   ['L' 'T']
# 124140   if_charging   ['T' 'L']
# 693436   if_charging   ['T' 'L']
# 453752   if_charging   ['T' 'L']
# 628041   if_charging   ['T' 'L']
# 378356   if_charging   ['L' 'T']
# 209945   if_charging   ['T' 'L']
# 245609   if_charging   ['L' 'T']
# 540712   if_charging   ['T' 'L']
# 103507   if_charging   ['L' 'T']
# 412240   if_charging   ['L' 'T']
# 713651   if_charging   ['T' 'L']
# 671482   if_charging   ['T' 'L']
# 580634   if_charging   ['L' 'T']
# 321683   if_charging   ['T' 'L']
# 735971   if_charging   ['T' 'L']
# 739296   if_charging   ['L' 'T']
# 392593   if_charging   ['L' 'T']
# 580470   if_charging   ['T' 'L']
# 526401   if_charging   ['T' 'L']
# 291086   if_charging   ['T' 'L']
# 914348   if_charging   ['L' 'T']
# 883691   if_charging   ['T' 'L']
# 923841   if_charging   ['T' 'L']
# 436105   if_charging   ['T' 'L']
# 961362   if_charging   ['L' 'T']
# 308913   if_charging   ['T' 'L']
# 250658   if_charging   ['T' 'L']
# 198427   if_charging   ['L' 'T']
# 651782   if_charging   ['T' 'L']
# 619401   if_charging   ['L' 'T']
# 348641   if_charging   ['L' 'T']
# 194450   if_charging   ['T' 'L']
# 206765   if_charging   ['T' 'L']
# 953842   if_charging   ['L' 'T']
# 395234   if_charging   ['L' 'T']
# 302513   if_charging   ['L' 'T']
# 810398   if_charging   ['L' 'T']
# 475895   if_charging   ['L' 'T']
# 815230   if_charging   ['T' 'L']
# 854548   if_charging   ['T' 'L']
# 905061   if_charging   ['T' 'L']
# 725137   if_charging   ['T' 'L']
# 175962   price_level   ['8-10W' '10-15W']
# 437598   price_level   ['10-15W' '15-20W']
# 603972   price_level   ['50-75W' '35-50W']
# 576298   price_level   ['5-8W' '10-15W']
# 384924   price_level   ['20-25W' '25-35W']
# 136916   price_level   ['15-20W' '25-35W' '20-25W']
# 597927   price_level   ['15-20W' '20-25W']
# 468392   price_level   ['20-25W' '15-20W']
# 356986   price_level   ['20-25W' '15-20W']
# 290854   price_level   ['15-20W' '20-25W']
# 732758   price_level   ['25-35W' '35-50W']
# 745137   price_level   ['10-15W' '15-20W']
# 714860   price_level   ['10-15W' '15-20W']
# 978089   price_level   ['5-8W' '8-10W']
# 219195   price_level   ['10-15W' '8-10W']
# 281792   price_level   ['25-35W' '20-25W']
# 354068   price_level   ['10-15W' '15-20W']
# 416749   price_level   ['10-15W' '15-20W']
# 125403   price_level   ['35-50W' '25-35W' '20-25W']
# 281301   price_level   ['25-35W' '20-25W']
# 654134   price_level   ['8-10W' '5-8W']
# 425432   price_level   ['10-15W' '15-20W']
# 871642   price_level   ['20-25W' '15-20W' '25-35W']
# 559132   price_level   ['20-25W' '25-35W' '15-20W']
# 819061   price_level   ['15-20W' '20-25W']
# 614059   price_level   ['35-50W' '25-35W']
# 527809   price_level   ['35-50W' '50-75W']
# 472603   price_level   ['10-15W' '15-20W']
# 453752   price_level   ['35-50W' '25-35W']
# 587678   price_level   ['15-20W' '10-15W']
# 628041   price_level   ['15-20W' '10-15W' '20-25W']
# 378356   price_level   ['8-10W' '5-8W']
# 209945   price_level   ['35-50W' '50-75W']
# 245609   price_level   ['15-20W' '10-15W']
# 905745   price_level   ['10-15W' '15-20W']
# 540712   price_level   ['15-20W' '10-15W']
# 103507   price_level   ['10-15W' '15-20W']
# 350259   price_level   ['15-20W' '20-25W']
# 221795   price_level   ['25-35W' '35-50W']
# 496459   price_level   ['5-8W' '8-10W']
# 321683   price_level   ['15-20W' '10-15W']
# 714152   price_level   ['25-35W' '15-20W']
# 739296   price_level   ['5-8W' '8-10W']
# 963845   price_level   ['10-15W' '15-20W']
# 741152   price_level   ['20-25W' '25-35W']
# 682651   price_level   ['35-50W' '25-35W']
# 401052   price_level   ['25-35W' '35-50W']
# 526401   price_level   ['10-15W' '8-10W']
# 560265   price_level   ['5-8W' '5WL']
# 291086   price_level   ['20-25W' '15-20W']
# 651347   price_level   ['8-10W' '5-8W']
# 914348   price_level   ['10-15W' '5-8W' '15-20W']
# 883691   price_level   ['20-25W' '25-35W']
# 923841   price_level   ['15-20W' '20-25W']
# 436105   price_level   ['15-20W' '10-15W']
# 481950   price_level   ['15-20W' '10-15W']
# 248352   price_level   ['8-10W' '10-15W' '5-8W']
# 961362   price_level   ['15-20W' '10-15W']
# 950264   price_level   ['15-20W' '10-15W']
# 308913   price_level   ['15-20W' '10-15W']
# 621073   price_level   ['5WL' '5-8W']
# 651782   price_level   ['35-50W' '50-75W']
# 348641   price_level   ['8-10W' '10-15W']
# 206765   price_level   ['15-20W' '10-15W']
# 953842   price_level   ['15-20W' '20-25W']
# 395234   price_level   ['15-20W' '20-25W']
# 360648   price_level   ['8-10W' '5-8W']
# 409854   driven_type_id   [1 3]
# 437598   driven_type_id   [1 3]
# 603972   driven_type_id   [1 3]
# 851857   driven_type_id   [3 1]
# 290854   driven_type_id   [1 3]
# 732758   driven_type_id   [3 1 2]
# 219195   driven_type_id   [1 3]
# 871642   driven_type_id   [3 1]
# 819061   driven_type_id   [1 3]
# 614059   driven_type_id   [2 3]
# 527809   driven_type_id   [2 3]
# 124140   driven_type_id   [1 3]
# 453752   driven_type_id   [2 3]
# 587678   driven_type_id   [1 3]
# 209945   driven_type_id   [2 3]
# 905745   driven_type_id   [1 3]
# 540712   driven_type_id   [3 1]
# 103507   driven_type_id   [1 3]
# 221795   driven_type_id   [1 3]
# 714152   driven_type_id   [3 1]
# 963845   driven_type_id   [1 3]
# 741152   driven_type_id   [1 3]
# 682651   driven_type_id   [3 1]
# 401052   driven_type_id   [3 1]
# 481950   driven_type_id   [3 1]
# 961362   driven_type_id   [1 3]
# 950264   driven_type_id   [1 3]
# 194450   driven_type_id   [1 3]
# 953842   driven_type_id   [1 3]
# 973106   driven_type_id   [3 1]
# 760412   driven_type_id   [3 1]
# 501564   driven_type_id   [1 3]
# 249875   driven_type_id   [3 1]
# 815230   driven_type_id   [1 3]
# 714150   driven_type_id   [3 1]
# 409854   fuel_type_id   [3 1]
# 437598   fuel_type_id   [3 1]
# 603972   fuel_type_id   [3 1]
# 576298   fuel_type_id   [3 1]
# 304458   fuel_type_id   [2 1]
# 384924   fuel_type_id   [2 1]
# 591790   fuel_type_id   [2 1]
# 136916   fuel_type_id   [2 1]
# 597927   fuel_type_id   [2 1]
# 468392   fuel_type_id   [2 1]
# 356986   fuel_type_id   [2 1]
# 851857   fuel_type_id   [2 1]
# 290854   fuel_type_id   [2 1]
# 732758   fuel_type_id   [2 1]
# 304458   newenergy_type_id   [2 1]
# 384924   newenergy_type_id   [2 1]
# 591790   newenergy_type_id   [2 1]
# 136916   newenergy_type_id   [2 1]
# 597927   newenergy_type_id   [2 1]
# 468392   newenergy_type_id   [2 1]
# 356986   newenergy_type_id   [2 1]
# 851857   newenergy_type_id   [2 1]
# 290854   newenergy_type_id   [2 1]
# 732758   newenergy_type_id   [4 1]
# 175962   emission_standards_id   [3 1]
# 961962   emission_standards_id   [3 1]
# 409854   emission_standards_id   [1 3]
# 603972   emission_standards_id   [3 1 5]
# 576298   emission_standards_id   [5 1 3]
# 304458   emission_standards_id   [1 3]
# 384924   emission_standards_id   [1 3]
# 591790   emission_standards_id   [1 3]
# 136916   emission_standards_id   [1 3]
# 597927   emission_standards_id   [1 3]
# 468392   emission_standards_id   [1 3]
# 290854   emission_standards_id   [1 3]
# 732758   emission_standards_id   [1 3]
# 714860   emission_standards_id   [1 3]
# 270690   emission_standards_id   [1 3]
# 219195   emission_standards_id   [1 3]
# 349023   emission_standards_id   [1 3]
# 281792   emission_standards_id   [1 3]
# 379876   emission_standards_id   [1 3]
# 347384   emission_standards_id   [1 3]
# 354068   emission_standards_id   [1 3]
# 416749   emission_standards_id   [1 3]
# 125403   emission_standards_id   [1 3]
# 786351   emission_standards_id   [1 3]
# 281301   emission_standards_id   [1 3]
# 654134   emission_standards_id   [1 3]
# 425432   emission_standards_id   [1 3]
# 559132   emission_standards_id   [1 3]
# 819061   emission_standards_id   [1 3]
# 482497   emission_standards_id   [1 3]
# 614059   emission_standards_id   [1 3]
# 527809   emission_standards_id   [1 3]
# 472603   emission_standards_id   [1 3]
# 124140   emission_standards_id   [1 3]
# 291514   emission_standards_id   [1 3]
# 854079   emission_standards_id   [1 3]
# 453752   emission_standards_id   [1 3]
# 587678   emission_standards_id   [1 3]
# 628041   emission_standards_id   [1 3]
# 209945   emission_standards_id   [1 3]
# 905745   emission_standards_id   [1 3]
# 265980   emission_standards_id   [1 3]
# 103507   emission_standards_id   [1 3]
# 516750   emission_standards_id   [1 3]
# 713651   emission_standards_id   [1 3]
# 671482   emission_standards_id   [1 3]
# 221795   emission_standards_id   [1 3]
# 580634   emission_standards_id   [1 3]
# 496459   emission_standards_id   [1 3]
# 321683   emission_standards_id   [1 3]
# 714152   emission_standards_id   [1 3]
# 735971   emission_standards_id   [1 3]
# 739296   emission_standards_id   [1 3]
# 289386   emission_standards_id   [1 3]
# 963845   emission_standards_id   [1 3]
# 580470   emission_standards_id   [1 3]
# 682651   emission_standards_id   [1 3]
# 560265   emission_standards_id   [1 3]
# 291086   emission_standards_id   [1 3]
# 651347   emission_standards_id   [1 3]
# 914348   emission_standards_id   [1 3]
# 883691   emission_standards_id   [1 3]
# 923841   emission_standards_id   [1 3]
# 436105   emission_standards_id   [1 3]
# 248352   emission_standards_id   [1 3]
# 961362   emission_standards_id   [1 3]
# 308913   emission_standards_id   [1 3]
# 621073   emission_standards_id   [1 3]
# 198427   emission_standards_id   [1 3]
# 651782   emission_standards_id   [1 3]
# 194450   emission_standards_id   [1 3]
# 178529   emission_standards_id   [1 3]
# 395234   emission_standards_id   [1 3]
# 360648   emission_standards_id   [1 3]
# 736094   emission_standards_id   [1 3]
# 175962   power   ['81/70' '81' '66' 81.0 66.0]
# 961962   power   ['81/70' '81' '66' '70' '96' 81.0 96.0 70.0 66.0]
# 527765   power   ['30' '36']
# 409854   power   ['110' '120' '145' '102' '98' 110.0 120.0 98.0]
# 437598   power   ['120' '110' '145' 145.0 110.0]
# 603972   power   ['140' '200' '150' '245' '165' '220' '228' '162' '132' '125' '188' '130'
#  '213' 125.0 220.0 228.0 162.0 140.0 213.0 130.0 132.0 150.0 200.0 245.0]
# 576298   power   ['82' '83' '89' '90' '85' '108' '81.58' '121' 89.0 83.0 82.0 81.58]
# 304458   power   ['73' '90' '85' '103' 90.0 103.0]
# 384924   power   ['91' '137' '120' '187' '166' '190' '195' '134' '184' 166.0 187.0 137.0
#  195.0 134.0 184.0 120.0]
# 591790   power   ['73' '90' '85' '103' 103.0 90.0]
# 136916   power   ['118' '110' '123' '135' '108' '109' 108.0 109.0 135.0 110.0 123.0]
# 597927   power   ['115' '132.4' '118' '180' '119' '121' '132' 121.0 119.0 132.0 180.0 118.0
#  132.4]
# 468392   power   ['107' '137' '114' '132' '192' '115' 115.0 137.0 114.0]
# 356986   power   ['107' '152' '135' '180' '182' 180.0 135.0 152.0]
# 851857   power   ['193' '179' 179.0 193.0]
# 290854   power   ['107' '114' '137' '142' '140' '125' '110' 140.0 114.0 137.0]
# 732758   power   ['111' '157' '150' '122' '128' 150.0 128.0 122.0 189.0 157.0 111.0]
# 289403   power   ['98' '95' 95.0 98.0]
# 745137   power   ['94' '135' '125' '92' 94.0 92.0 125.0 135.0]
# 714860   power   ['105' '114' '128.7' 105.0 114.0 128.7]
# 270690   power   ['82' '65' '60.3' 82.0 65.0 60.3]
# 692703   power   ['101' '112' 101.0 112.0]
# 978089   power   ['80' '98' 80.0 98.0]
# 219195   power   ['110' 110.0]
# 349023   power   ['84' '86' '80' '110' '135' '89' '131' '108' '105' 86.0 80.0 89.0 131.0
#  108.0 84.0 110.0]
# 281792   power   ['132' '110' '140' 110.0 132.0]
# 510309   power   ['155' '135' '180' 135.0 155.0 180.0]
# 379876   power   ['100' '86' '123' '108' '78' 78.0 86.0]
# 750340   power   ['115' 115.0]
# 347384   power   ['93.8' '95.6' '107' 107.0 93.8 95.6]
# 354068   power   ['93' '86' '102' '105' 86.0 102.0 93.0]
# 416749   power   ['96' '100' 100.0 96.0]
# 125403   power   ['187' '120' '134' '186' '191' '142' '123' '137' '190' 123.0 190.0 134.0
#  187.0 120.0 137.0]
# 786351   power   ['93.8' '107' 93.8]
# 281301   power   ['162' '110' '118' '132' '96' '184' '147' 147.0 118.0 96.0 162.0 132.0
#  110.0]
# 654134   power   ['101' '110' 101.0 110.0]
# 425432   power   ['81' '110' '96' '88' '77' 81.0 77.0 96.0 110.0]
# 871642   power   ['133' '135' '182' '178' '130' 178.0 130.0 133.0]
# 559132   power   ['137' '104' '110' '171' 171.0 104.0 137.0 110.0]
# 819061   power   ['121' '128' '120' 121.0 120.0 128.0]
# 482497   power   ['165' '169' '155' 155.0 165.0]
# 614059   power   ['135' '115' '180' '150' '155' 115.0 180.0 155.0 135.0]
# 527809   power   ['135' '180' '155' '200' '150' '125' 150.0 155.0 200.0 180.0 135.0 125.0]
# 472603   power   ['102' '123' '100' '108' '78' '86' 78.0 86.0 108.0 102.0 123.0 100.0]
# 124140   power   ['130' '116' '125' 130.0 116.0]
# 291514   power   ['92' 92.0]
# 693436   power   ['95' '98']
# 649213   power   ['200' '164' 200.0 164.0]
# 854079   power   ['100' '102' 102.0 100.0]
# 453752   power   ['135' '100' '150' '111' '185' '200' '112' '160' 150.0 111.0 112.0 200.0
#  160.0]
# 587678   power   ['100' '96' 100.0 96.0]
# 924154   power   ['85' 85.0]
# 628041   power   ['110' '96' '81' '162' '147' '77' 77.0 96.0 110.0 147.0 81.0 162.0]
# 378356   power   ['85' '108' 85.0]
# 209945   power   ['150' '200' '178' '250' '185' '165' '144' '167' '211' 167.0 178.0 250.0
#  150.0 211.0 200.0]
# 245609   power   ['81' '96' '110' 96.0 110.0 81.0]
# 905745   power   ['103' '105' 103.0 105.0]
# 540712   power   ['135' '104' '120' 135.0 120.0]
# 265980   power   ['68' '78' 78.0 68.0]
# 103507   power   ['91.6' '117.7' '118' 118.0 117.7 91.6]
# 516750   power   ['82' 82.0]
# 412240   power   ['86' '110' 86.0]
# 350259   power   ['96' '162' '110' '132' 96.0 110.0 132.0 162.0]
# 713651   power   ['130' '92' '104' '114' '103' 104.0 114.0 130.0]
# 671482   power   ['94' '83' '90' '92' '81' 83.0 81.0 92.0 94.0]
# 221795   power   ['132' '110' '162' '125' '147' 125.0 110.0 147.0 132.0]
# 492952   power   ['93' 93.0]
# 580634   power   ['93' '140' 93.0 140.0]
# 496459   power   ['93' 93.0]
# 321683   power   ['110' '96' '81' '147' '77' '74' '118' 74.0 77.0 96.0 81.0 147.0 110.0]
# 714152   power   ['118' '147' '110' '162' '132' '96' 118.0 96.0 147.0]
# 735971   power   ['103' '81' '85' '135' '108' '89' '86' '105' '131' 89.0 108.0 81.0 86.0
#  103.0]
# 739296   power   ['82' '110' '101' 82.0 101.0 110.0]
# 289386   power   ['116' '86' 116.0 86.0]
# 392593   power   ['90' '112' '108' 90.0]
# 963845   power   ['91.6' '118' 91.6 118.0]
# 580470   power   ['96' '81' '77' '74' 77.0 96.0 74.0 81.0]
# 741152   power   ['119' '186' 186.0 119.0]
# 682651   power   ['165' '140' '132' '185' '118' '155' 118.0 165.0 132.0]
# 401052   power   ['135' '115' '155' 115.0 135.0 155.0]
# 526401   power   ['95.6' '93.8' '95.3' 95.3 93.8 95.6]
# 379265   power   ['60.3' '82']
# 560265   power   ['75' '63.5' '85' '78' 75.0 78.0 85.0 63.5]
# 291086   power   ['184' '108' '131' '120' '187' '166' '132' '137' '134' '113' '135' '125'
#  131.0 137.0 108.0 184.0 135.0 113.0 134.0]
# 651347   power   ['96' '88' '73' 73.0 88.0 96.0]
# 914348   power   ['81' '66' '110' '77' '63' '96' 77.0 63.0 66.0 96.0 81.0 110.0]
# 883691   power   ['132' '110' '118' '162' '147' '96' '184' 118.0 147.0 184.0 162.0 132.0]
# 923841   power   ['120' '131' '108' '135' '113' '137' '134' 113.0 131.0 108.0 135.0 137.0
#  134.0]
# 436105   power   ['128.7' '105' '114' 105.0 128.7]
# 481950   power   ['141' '116' 116.0 141.0]
# 248352   power   ['78.7' '90.2' '73.3' '90.4' 78.7 90.4]
# 961362   power   ['110' '86' '89' '106' 106.0 110.0 86.0]
# 950264   power   ['162' '124' 162.0 124.0]
# 308913   power   ['96' '81' 81.0 96.0]
# 250658   power   ['120' '142' 120.0]
# 621073   power   ['60.3' '82' '65' '63' 82.0 63.0 65.0 60.3]
# 198427   power   ['80' '78' '98' 80.0]
# 651782   power   ['193' '198' '227' 198.0 193.0 227.0]
# 619401   power   ['98' 98.0]
# 348641   power   ['80' '115' 80.0 115.0]
# 194450   power   ['130' '121' '104' 130.0 104.0 121.0]
# 206765   power   ['119' '84' 84.0 119.0]
# 178529   power   ['60.3' '45' '63' '60' '61.5' '50' 45.0 63.0 50.0 60.3]
# 953842   power   ['121' '130' 121.0 130.0]
# 395234   power   ['108' '150' '123' '126' 108.0 123.0 126.0 150.0]
# 302513   power   ['88' '115']
# 973106   power   ['200' '142']
# 760412   power   ['141' '122']
# 360648   power   ['79' '73' 79.0 73.0]
# 736094   power   ['84' 84.0]
# 378536   power   ['150' '123']
# 186250   power   ['84' 84.0]
# 810398   power   ['81' '66' '96' 96.0 81.0]
# 475895   power   ['81' '96']
# 249875   power   ['137' '110']
# 815230   power   ['121' '128.5']
# 861459   power   ['124' '92']
# 437063   power   ['100' '141']
# 854548   power   ['92' '88']
# 789290   power   ['79' '73']
# 714150   power   ['127' '186']
# 687270   power   ['82' '60.3']
# 905061   power   ['115' '92']
# 725137   power   ['101' '84']
# 603972   cylinder_number   [6 4]
# 384924   cylinder_number   [4 6]
# 468392   cylinder_number   [4 6]
# 732758   cylinder_number   [3 4]
# 745137   cylinder_number   [4 3]
# 379876   cylinder_number   [3 4]
# 125403   cylinder_number   [6 4]
# 281301   cylinder_number   [4 6]
# 559132   cylinder_number   [4 6]
# 614059   cylinder_number   [4 6]
# 527809   cylinder_number   [4 6]
# 472603   cylinder_number   [4 3]
# 453752   cylinder_number   [4 3 6]
# 209945   cylinder_number   [4 6]
# 713651   cylinder_number   [4 3]
# 671482   cylinder_number   [3 4]
# 735971   cylinder_number   [4 3]
# 883691   cylinder_number   [4 6]
# 651782   cylinder_number   [4 6]
# 861459   cylinder_number   [4 3]
# 437063   cylinder_number   [3 4]
# 854548   cylinder_number   [3 4]
# 175962   engine_torque   ['147.5' '155' '132' 155.0 132.0]
# 961962   engine_torque   ['147.5' '160' '132' '155' '150' '140' '225' 160.0 155.0 225.0 140.0 132.0]
# 409854   engine_torque   ['310' '350' '210' '315' '235' '186' 210.0 186.0]
# 437598   engine_torque   ['350' '210' '315' 315.0 210.0]
# 603972   engine_torque   ['380' '400' '320' '250' '440' '350' '280' '330' '230' '420' 280.0 440.0
#  250.0 420.0 230.0 320.0 400.0]
# 576298   engine_torque   ['235' '138' '168' '140' '153' '143' '200' '162.68' '130' '215' 168.0 138.0
#  130.0 162.68 140.0]
# 304458   engine_torque   ['142' '154' '185' '173' 154.0 173.0]
# 384924   engine_torque   ['175' '240' '252' '350' '296' 350.0 296.0 240.0 252.0]
# 591790   engine_torque   ['142' '154' '185' '173' 173.0 154.0]
# 136916   engine_torque   ['213' '187' '199' '235' '190' '224' 190.0 235.0 199.0]
# 597927   engine_torque   ['189' '265' '193' '350' '194' '198' '231' 198.0 194.0 231.0 350.0 193.0
#  265.0]
# 468392   engine_torque   ['175' '243' '190' '225' '297' '189' 189.0 243.0 190.0]
# 356986   engine_torque   ['174.9' '340' '350' '240' 350.0 240.0 340.0]
# 851857   engine_torque   ['350' '400' 400.0]
# 290854   engine_torque   ['175' '190' '243' '222' '220' 222.0 190.0 243.0]
# 732758   engine_torque   ['220' '280' '270' '195' '240' 270.0 240.0 195.0 350.0 280.0 220.0]
# 289403   engine_torque   ['170' '185' 185.0 170.0]
# 745137   engine_torque   ['159' '240' '170' '202' 170.0 159.0 202.0 240.0]
# 714860   engine_torque   ['176' '192' '265' 176.0 192.0 265.0]
# 270690   engine_torque   ['146.5' '116' 146.5 116.0]
# 692703   engine_torque   ['202' '235' 202.0 235.0]
# 978089   engine_torque   ['140' '185' 140.0 185.0]
# 219195   engine_torque   ['210' 210.0]
# 349023   engine_torque   ['146' '155' '141' '240' '235' '150' '177' 155.0 141.0 235.0 177.0 146.0]
# 281792   engine_torque   ['300' '250' '320' 250.0 300.0]
# 510309   engine_torque   ['350' '300' '370' 300.0 350.0 370.0]
# 379876   engine_torque   ['230' '150' '245' '200' '142' 142.0 150.0]
# 750340   engine_torque   ['215' 215.0]
# 347384   engine_torque   ['155.5' '210.8' '175' 175.0 155.5 210.8]
# 354068   engine_torque   ['154' '153' '174' '189' 153.0 174.0 154.0]
# 416749   engine_torque   ['155' '169' 169.0 155.0]
# 125403   engine_torque   ['290' '225' '240' '350' '253' 225.0 290.0 240.0]
# 786351   engine_torque   ['155.5' '175' 155.5]
# 281301   engine_torque   ['350' '250' '300' '220' '310' '280' 280.0 250.0 220.0 350.0 300.0]
# 654134   engine_torque   ['186' '230' 186.0 230.0]
# 425432   engine_torque   ['155' '250' '225' '180' '200' '220' 155.0 220.0 225.0 250.0]
# 871642   engine_torque   ['240' '350' 350.0 240.0]
# 559132   engine_torque   ['234' '190' '195' '232' 232.0 190.0 234.0 195.0]
# 819061   engine_torque   ['199' '226' '194' 199.0 194.0 226.0]
# 482497   engine_torque   ['350' 350.0]
# 614059   engine_torque   ['300' '250' '370' '310' '230' '270' '350' 250.0 370.0 350.0 300.0]
# 527809   engine_torque   ['300' '370' '350' '400' '310' '270' '280' 310.0 350.0 400.0 300.0 280.0
#  370.0]
# 472603   engine_torque   ['172' '245' '230' '200' '142' '150' 142.0 150.0 200.0 172.0 245.0 230.0]
# 124140   engine_torque   ['230' '200' '245' 230.0 200.0 245.0]
# 291514   engine_torque   ['160' 160.0]
# 693436   engine_torque   ['185' '170']
# 649213   engine_torque   ['400' '353' 400.0 353.0]
# 854079   engine_torque   ['169' '172' 172.0 169.0]
# 453752   engine_torque   ['270' '220' '350' '200' '250' 270.0 220.0 200.0 350.0 250.0]
# 587678   engine_torque   ['169' '155' 169.0 155.0]
# 924154   engine_torque   ['142' 142.0]
# 628041   engine_torque   ['250' '225' '155' '350' '220' '280' '200' 155.0 225.0 250.0 280.0 220.0
#  200.0 350.0]
# 378356   engine_torque   ['141' '210' 141.0]
# 209945   engine_torque   ['270' '350' '310' '400' '230' '250' 250.0 310.0 400.0 270.0 350.0]
# 245609   engine_torque   ['155' '225' '250' 225.0 250.0 155.0]
# 905745   engine_torque   ['200' '205' 200.0]
# 540712   engine_torque   ['285' '178' '250' 285.0 250.0]
# 265980   engine_torque   ['120' '135' 135.0 120.0]
# 103507   engine_torque   ['150.7' '250' '192' 192.0 250.0 150.7]
# 516750   engine_torque   ['146.5' 146.5]
# 412240   engine_torque   ['150' '230' 150.0]
# 350259   engine_torque   ['225' '350' '250' '300' 225.0 250.0 300.0 350.0]
# 713651   engine_torque   ['220' '226' '173' '174' '190' 174.0 190.0 220.0 226.0]
# 671482   engine_torque   ['170' '140' '150' 140.0 170.0]
# 221795   engine_torque   ['320' '250' '350' '280' 280.0 250.0 320.0]
# 492952   engine_torque   ['154' 154.0]
# 580634   engine_torque   ['154' '240' 154.0 240.0]
# 496459   engine_torque   ['160' 160.0]
# 321683   engine_torque   ['250' '225' '155' '200' '280' '220' '145' 145.0 155.0 220.0 280.0 250.0
#  225.0]
# 714152   engine_torque   ['250' '280' '350' '300' '220' 250.0 220.0 280.0]
# 735971   engine_torque   ['200' '143' '170' '235' '177' '150' 150.0 177.0 143.0 200.0]
# 739296   engine_torque   ['146.5' '230' '186' 146.5 186.0 230.0]
# 289386   engine_torque   ['202' '148' 202.0 148.0]
# 392593   engine_torque   ['180' '205' '210' 180.0]
# 963845   engine_torque   ['150.7' '192' 150.7 192.0]
# 580470   engine_torque   ['225' '155' '150' '220' '145' 155.0 220.0 145.0 225.0]
# 741152   engine_torque   ['250' '353' 353.0 250.0]
# 682651   engine_torque   ['350' '320' '370' '250' 250.0 350.0 320.0]
# 401052   engine_torque   ['300' '250' '350' 250.0 300.0 350.0]
# 526401   engine_torque   ['210.8' '155.5' '157' 157.0 155.5 210.8]
# 379265   engine_torque   ['116' '146.5']
# 560265   engine_torque   ['135' '108' '150' '145' 135.0 145.0 150.0 108.0]
# 291086   engine_torque   ['350' '190' '235' '252' '230' '240' '225' 235.0 240.0 190.0 350.0]
# 651347   engine_torque   ['155' '145' '127' 127.0 145.0 155.0]
# 914348   engine_torque   ['155' '132' '250' '130' '220' 155.0 132.0 220.0 130.0 250.0]
# 883691   engine_torque   ['300' '250' '350' '280' '220' '310' 250.0 280.0 310.0 350.0 300.0]
# 923841   engine_torque   ['250.3' '235' '190' '240' 190.0 235.0 240.0]
# 436105   engine_torque   ['265' '176' '192' 176.0 265.0]
# 481950   engine_torque   ['252' '202' 202.0 252.0]
# 248352   engine_torque   ['135' '150.7' '132.4' '155' 135.0 155.0]
# 961362   engine_torque   ['200' '165' '154' '198' 198.0 200.0 165.0 190.0]
# 950264   engine_torque   ['350' '250' 350.0 250.0]
# 308913   engine_torque   ['225' '155' '200' 155.0 225.0]
# 250658   engine_torque   ['252' '253' 252.0]
# 621073   engine_torque   ['116' '146.5' '108' 146.5 108.0 116.0]
# 198427   engine_torque   ['140' '142' '185' 140.0]
# 651782   engine_torque   ['400' '355' '360' 355.0 400.0 360.0]
# 619401   engine_torque   ['170' '185' 170.0 185.0]
# 348641   engine_torque   ['135' '235' 135.0 235.0]
# 194450   engine_torque   ['265' '203' '184' 265.0 184.0 203.0]
# 206765   engine_torque   ['250' '146' 146.0 250.0]
# 178529   engine_torque   ['115' '85' '108' '103' '116' '90' 85.0 108.0 90.0 115.0]
# 953842   engine_torque   ['203' '265' 203.0 265.0]
# 395234   engine_torque   ['200' '280' '245' '230' 200.0 245.0 230.0 280.0]
# 302513   engine_torque   ['143' '215']
# 973106   engine_torque   ['370' '243']
# 760412   engine_torque   ['235' '201' '190']
# 360648   engine_torque   ['140' '123' 140.0 123.0]
# 736094   engine_torque   ['148' 148.0]
# 378536   engine_torque   ['280' '245']
# 186250   engine_torque   ['146' 146.0]
# 810398   engine_torque   ['155' '132' '225' 225.0 155.0]
# 475895   engine_torque   ['155' '225']
# 249875   engine_torque   ['233' '200']
# 815230   engine_torque   ['250' '227.5']
# 861459   engine_torque   ['250' '170']
# 437063   engine_torque   ['220' '280']
# 854548   engine_torque   ['170' '150']
# 789290   engine_torque   ['140' '123']
# 714150   engine_torque   ['275' '353']
# 687270   engine_torque   ['146.5' '116']
# 905061   engine_torque   ['225' '160']
# 725137   engine_torque   ['202' '150']
# 175962   car_length   [4473 4475]
# 961962   car_length   [4487 4501 4415]
# 409854   car_length   [4640 4649 4681 4600]
# 437598   car_length   [4549 4545 4589]
# 603972   car_length   [5035 5036 5015 5012]
# 576298   car_length   [5115 4715 5055 4680 5145 4745 4645 4655]
# 304458   car_length   [4630 4545]
# 384924   car_length   [5018 5000 5005]
# 136916   car_length   [4850 4825]
# 597927   car_length   [4855 4845]
# 468392   car_length   [4915 4930 4945 4960]
# 356986   car_length   [4873 4860]
# 290854   car_length   [4585 4550 4530 4575]
# 732758   car_length   [4565 4477 4484 4469]
# 745137   car_length   [4534 4368]
# 978089   car_length   [4425 4631]
# 219195   car_length   [4335 4365]
# 349023   car_length   [4567 4666 4510 4643 4450 4598]
# 281792   car_length   [4319 4462 4312 4457]
# 379876   car_length   [4590 4558]
# 354068   car_length   [4631 4665 4610]
# 125403   car_length   [5266 5213 5203 5256]
# 281301   car_length   [4872 4870]
# 654134   car_length   [4620 4670]
# 425432   car_length   [4605 4608]
# 559132   car_length   [4891 4868 5016 4850 5003 4930]
# 819061   car_length   [4450 4440]
# 614059   car_length   [4783 4714 4581]
# 527809   car_length   [5065 4925 5024 5012 5026]
# 472603   car_length   [4750 4688 4680]
# 291514   car_length   [4160 4170]
# 854079   car_length   [4664 4650]
# 453752   car_length   [4760 4753 4755 4645 4734 4643 4650 4531]
# 628041   car_length   [4255 4275 4199 4213]
# 209945   car_length   [5055 5087 5039]
# 265980   car_length   [4360 4420]
# 516750   car_length   [4530 4500]
# 412240   car_length   [4680 4705]
# 350259   car_length   [4598 4610]
# 713651   car_length   [4649 4535 4500 4565]
# 671482   car_length   [4280 4345]
# 221795   car_length   [4398 4385]
# 580634   car_length   [4393 4295]
# 321683   car_length   [4655 4664 4644 4544]
# 714152   car_length   [4506 4712 4525]
# 735971   car_length   [4587 4609 4671]
# 739296   car_length   [4685 4710 4780]
# 289386   car_length   [4582 4461]
# 580470   car_length   [4562 4523 4540]
# 682651   car_length   [4761 4818 4763]
# 401052   car_length   [4431 4452 4449]
# 291086   car_length   [4834 4843 4902 4830]
# 651347   car_length   [4065 3900]
# 914348   car_length   [3987 3970 3975 4176 4200]
# 603972   wheelbase   [2945 3012]
# 576298   wheelbase   [3000 2800]
# 304458   wheelbase   [2700 2600]
# 384924   wheelbase   [2905 2837]
# 597927   wheelbase   [2805 2795]
# 468392   wheelbase   [2775 2800]
# 290854   wheelbase   [2660 2620]
# 732758   wheelbase   [2780 2760]
# 349023   wheelbase   [2662 2700 2685]
# 379876   wheelbase   [2675 2612]
# 871642   wheelbase   [2690 2640]
# 559132   wheelbase   [2775 2900]
# 614059   wheelbase   [2920 2840 2760]
# 527809   wheelbase   [3079 2939 3014]
# 472603   wheelbase   [2730 2710]
# 453752   wheelbase   [2920 2810 2760]
# 628041   wheelbase   [2637 2631 2578]
# 713651   wheelbase   [2700 2670]
# 321683   wheelbase   [2651 2578]
# 714152   wheelbase   [2684 2791]
# 735971   wheelbase   [2640 2685]
# 580470   wheelbase   [2614 2610]
# 682651   wheelbase   [2869 2908]
# 291086   wheelbase   [2737 2829]
# 651347   wheelbase   [2530 2500]
# 914348   wheelbase   [2470 2465 2460]
# 883691   wheelbase   [2871 2812]
# 248352   wheelbase   [2570 2600]
# 961362   wheelbase   [2646 2630]
# 198427   wheelbase   [2600 2602]
# 194450   wheelbase   [2670 2630]
# 178529   wheelbase   [2750 2500]
# 961962   front_track   [1460 1429]
# 409854   front_track   [1565 1585]
# 603972   front_track   [1612 1630 1627]
# 304458   front_track   [1535 1525]
# 384924   front_track   [1599 1565 1580 1578]
# 591790   front_track   [1535 1525]
# 597927   front_track   [1614 1602 1601 1591 1595]
# 468392   front_track   [1585 1595 1590]
# 356986   front_track   [1590 1578]
# 290854   front_track   [1601 1580 1598 1565]
# 732758   front_track   [1561 1500]
# 349023   front_track   [1540 1541 1545 1544 1535]
# 281792   front_track   [1539 1552 1534 1547]
# 379876   front_track   [1555 1525]
# 354068   front_track   [1540 1480 1530 1475]
# 125403   front_track   [1593 1586 1612 1602]
# 786351   front_track   [1549 1551]
# 559132   front_track   [1585 1560 1550]
# 614059   front_track   [1572 1563 1541]
# 527809   front_track   [1596 1597 1578 1580 1579]
# 472603   front_track   [1555 1522]
# 453752   front_track   [1537 1543 1531 1506 1500]
# 628041   front_track   [1549 1538 1540 1533]
# 209945   front_track   [1600 1604 1605 1594]
# 713651   front_track   [1547 1495]
# 671482   front_track   [1527 1555]
# 221795   front_track   [1547 1571]
# 492952   front_track   [1540 1530]
# 580634   front_track   [1530 1540]
# 321683   front_track   [1535 1539]
# 714152   front_track   [1569 1582]
# 735971   front_track   [1538 1544]
# 739296   front_track   [1530 1546]
# 580470   front_track   [1518 1517]
# 682651   front_track   [1564 1566]
# 401052   front_track   [1558 1553 1540 1545]
# 291086   front_track   [1585 1603]
# 651347   front_track   [1480 1490]
# 914348   front_track   [1463 1451 1435]
# 883691   front_track   [1584 1552]
# 436105   front_track   [1567 1579]
# 248352   front_track   [1511 1524 1489]
# 961362   front_track   [1585 1540]
# 250658   front_track   [1606 1596]
# 198427   front_track   [1490 1482]
# 194450   front_track   [1620 1550]
# 206765   front_track   [1540 1534]
# 178529   front_track   [1290 1280]
# 395234   front_track   [1584 1590]
# 360648   front_track   [1460 1470]
# 815230   front_track   [1544 1545]
# 437063   front_track   [1563 1559]
# 789290   front_track   [1460 1470]
# 961962   rear_track   [1500 1422]
# 409854   rear_track   [1565 1585]
# 603972   rear_track   [1622 1620 1618]
# 304458   rear_track   [1535 1520]
# 384924   rear_track   [1602 1574 1576]
# 591790   rear_track   [1535 1520]
# 597927   rear_track   [1621 1609 1601 1591 1595]
# 468392   rear_track   [1580 1585]
# 356986   rear_track   [1587 1574]
# 290854   rear_track   [1617 1580 1613 1565]
# 732758   rear_track   [1562 1529]
# 349023   rear_track   [1558 1561 1567 1565 1557]
# 281792   rear_track   [1509 1520 1506 1522]
# 379876   rear_track   [1550 1522]
# 354068   rear_track   [1540 1485 1530 1480]
# 125403   rear_track   [1603 1596 1626 1605 1601]
# 786351   rear_track   [1562 1564]
# 559132   rear_track   [1585 1560 1550]
# 482497   rear_track   [1614 1613]
# 614059   rear_track   [1538 1545 1530 1544]
# 527809   rear_track   [1600 1590 1581 1589 1582 1594 1599 1596]
# 472603   rear_track   [1550 1503]
# 453752   rear_track   [1576 1582 1572 1584 1535 1529]
# 628041   rear_track   [1520 1515 1513 1514]
# 209945   rear_track   [1627 1628 1631 1599]
# 713651   rear_track   [1563 1520]
# 671482   rear_track   [1533 1560]
# 221795   rear_track   [1555 1575]
# 492952   rear_track   [1540 1530]
# 580634   rear_track   [1530 1540]
# 321683   rear_track   [1532 1528]
# 714152   rear_track   [1571 1572]
# 735971   rear_track   [1541 1558]
# 739296   rear_track   [1525 1541]
# 963845   rear_track   [1570 1568]
# 580470   rear_track   [1525 1493]
# 682651   rear_track   [1550 1549]
# 401052   rear_track   [1549 1544 1547 1552]
# 291086   rear_track   [1588 1607 1589 1587]
# 651347   rear_track   [1465 1475]
# 914348   rear_track   [1456 1444 1425]
# 883691   rear_track   [1570 1551]
# 436105   rear_track   [1577 1589]
# 481950   rear_track   [1587 1586]
# 248352   rear_track   [1515 1529 1493]
# 961362   rear_track   [1581 1545]
# 250658   rear_track   [1609 1599]
# 198427   rear_track   [1470 1462]
# 194450   rear_track   [1631 1550]
# 206765   rear_track   [1558 1552]
# 395234   rear_track   [1551 1572]
# 360648   rear_track   [1460 1470]
# 815230   rear_track   [1544 1545]
# 437063   rear_track   [1565 1561]
# 789290   rear_track   [1460 1470]

# %%
df.groupby('price_level')['sale_quantity'].sum()
# Out:
# price_level
# 10-15W    1158367
# 15-20W     444910
# 20-25W     179928
# 25-35W     125177
# 35-50W     117719
# 5-8W       192779
# 50-75W      32600
# 5WL        138105
# 8-10W      156487
# Name: sale_quantity, dtype: int64

# %%
df.groupby('rated_passenger')['sale_quantity'].sum()
# Out:
# rated_passenger
# 04-May       2380
# 05-Aug        247
# 05-Jul         64
# 06-Aug      10613
# 06-Jul      38401
# 07-Aug     139670
# 4             651
# 5         2292229
# 7           61801
# 9              16
# Name: sale_quantity, dtype: int64
