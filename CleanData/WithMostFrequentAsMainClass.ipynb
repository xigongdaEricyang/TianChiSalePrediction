# %%
import pandas as pd
from parse import parse
import numpy as np

# %%
all_data_df = pd.read_csv('trainDataAfterClean.csv')

# %%
final_df = pd.read_csv(r'C:\Users\YW59785\Desktop\tianchi\model2\final.csv')

# %%
all_data_df.columns[final_df.columns != all_data_df.columns]
# Out:
# Index(['month_01', 'month_02', 'month_03', 'month_04', 'month_05', 'month_06',
#        'month_07', 'month_08', 'month_09'],
#       dtype='object')

# %%
year_columns = [c for c in all_data_df.columns.values if c.find('month_') >-1]
month_columns = [c for c in all_data_df.columns.values if c.find('year_') >-1]
classid_columns =  [c for c in all_data_df.columns.values if c.find('class_id_') >-1]

# %%
idx = all_data_df.groupby(year_columns + month_columns + classid_columns)['sale_quantity'].transform(max) == all_data_df['sale_quantity']

# %%
all_data_df[idx].to_csv('Max_trainDataAfterClean.csv', index=False)

# %%
all_data_df.shape
# Out:
# (20157, 246)

# %%
all_data_df[idx]
# Out:
#        sale_quantity  compartment  level_id   TR  displacement  if_charging  \
# 3                195            2       5.0  1.0           0.0            1
# 5                 35            2       5.0  1.0           0.0            1
# 6                 59            2       5.0  1.0           0.0            1
# 7                  6            2       5.0  1.0           0.0            1
# 8                  6            2       5.0  1.0           0.0            1
# 9                 24            2       5.0  1.0           0.0            1
# 10                30            2       5.0  1.0           0.0            1
# 11                41            2       5.0  1.0           0.0            1
# 14                53            2       5.0  1.0           0.0            1
# 15                47            2       5.0  1.0           0.0            1
# 16                18            2       5.0  1.0           0.0            1
# ...
