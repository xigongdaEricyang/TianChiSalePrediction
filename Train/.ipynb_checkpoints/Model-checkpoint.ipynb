# %%
import tensorflow as tf
import mnist_inference
import os
import pandas as pd
from sklearn.preprocessing import normalize
import numpy as np
from sklearn.model_selection import train_test_split

# %%
BATCH_SIZE = 200 
LEARNING_RATE_BASE = 0.99
LEARNING_RATE_DECAY = 0.99
REGULARIZATION_RATE = 0.03
TRAINING_STEPS = 1500

# %%
MOVING_AVERAGE_DECAY = 0.49
MODEL_SAVE_PATH = "../model/{}".format(pd.Timestamp.now())[:19]
MODEL_NAME = "tianchi_model"
TENSORBOARD_LOG = 'tensor_board'

# %%
def train(trainX, trainY, testX, testY):
    dataSize = len(trainY)
    
    with tf.device('/gpu:0'):
        # 定义输入输出placeholder。
        x = tf.placeholder(tf.float32, [None, mnist_inference.INPUT_NODE], name='x-input')
        y_ = tf.placeholder(tf.float32, [None, mnist_inference.OUTPUT_NODE], name='y-input')

        regularizer = tf.contrib.layers.l2_regularizer(REGULARIZATION_RATE)
        y = mnist_inference.inference(x, regularizer)
        global_step = tf.Variable(0, trainable=False)
    
        # 定义损失函数、学习率、滑动平均操作以及训练过程。
        variable_averages = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY, global_step)
        variables_averages_op = variable_averages.apply(tf.trainable_variables())
        #cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y, labels=tf.argmax(y_, 1))
        #cross_entropy_mean = tf.reduce_mean(cross_entropy)
        beginLoss = tf.sqrt(tf.reduce_mean(tf.pow(tf.subtract(y, y_), 2)))
        #loss = beginLoss + tf.add_n(tf.get_collection('losses'))
        loss = beginLoss
        learning_rate = tf.train.exponential_decay(
            LEARNING_RATE_BASE,
            global_step,
            dataSize / BATCH_SIZE, LEARNING_RATE_DECAY,
            staircase=True)
        train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
        with tf.control_dependencies([train_step, variables_averages_op]):
            train_op = tf.no_op(name='train')
        
    # 初始化TensorFlow持久化类。
    saver = tf.train.Saver()
    with tf.Session(config=tf.ConfigProto(
      allow_soft_placement=True, log_device_placement=True)) as sess:
        tf.global_variables_initializer().run()
        
        for i in range(TRAINING_STEPS):
            for start in range(0, len(trainX)-BATCH_SIZE, BATCH_SIZE):
                end = start + BATCH_SIZE
                if end <=len(trainX):
                    x_batch, y_batch = trainX[start: end], trainY[start: end]
                else: 
                    x_batch, y_batch = trainX[start: ], trainY[start: ]
                _, loss_value, step = sess.run([train_op, loss, global_step], feed_dict={x: x_batch, y_: y_batch})
                if start % len(trainX) == 0:
                    print("After", step," training step(s), loss on training batch is ", loss_value)
            if i % 5 == 0:
                test_loss = sess.run(loss, feed_dict={x:test_x, y_: test_y})
                print("rang", i, "current test loss value on test set is ", test_loss)
        saver.save(sess, os.path.join(MODEL_SAVE_PATH, MODEL_NAME), global_step=global_step)

# %%
df = pd.read_csv('../CleanData/Max_trainDataAfterClean.csv')
# random shift the df
df = df.sample(frac=1).reset_index(drop=True)

normalizeColumns = ['compartment','TR','displacement','price_level','power','level_id',
                    'cylinder_number','engine_torque','car_length','car_height','car_width','total_quality','equipment_quality',
                    'rated_passenger','wheelbase','front_track','rear_track']
leftDf = df.drop(normalizeColumns, axis =1 ).drop(['sale_quantity'], axis = 1)

normalizeDf = df[normalizeColumns]
normalizeDf = (normalizeDf-normalizeDf.min())/(normalizeDf.max()-normalizeDf.min())
inputDf = pd.concat([leftDf, normalizeDf], axis = 1)
inputX = inputDf.values
resultArray = df['sale_quantity'].values
inputY = resultArray.reshape((len(resultArray),1))

train_x, test_x, train_y, test_y = train_test_split(inputX, inputY, test_size=0.2, random_state=42)

# %%
train(train_x, train_y, test_x, test_y)
# Out:
# After 1  training step(s), loss on training batch is  475.747
# rang 0 current test loss value on test set is  481.787
# After 24  training step(s), loss on training batch is  470.225
# After 47  training step(s), loss on training batch is  462.832
# After 70  training step(s), loss on training batch is  357.206
# After 93  training step(s), loss on training batch is  454.618
# After 116  training step(s), loss on training batch is  449.601
# rang 5 current test loss value on test set is  458.101
# After 139  training step(s), loss on training batch is  444.002
# After 162  training step(s), loss on training batch is  439.231
# After 185  training step(s), loss on training batch is  434.937
# After 208  training step(s), loss on training batch is  430.33
# After 231  training step(s), loss on training batch is  388.531
# rang 10 current test loss value on test set is  439.777
# After 254  training step(s), loss on training batch is  423.302
# After 277  training step(s), loss on training batch is  419.678
# After 300  training step(s), loss on training batch is  415.04
# After 323  training step(s), loss on training batch is  410.791
# After 346  training step(s), loss on training batch is  353.28
# rang 15 current test loss value on test set is  424.231
# After 369  training step(s), loss on training batch is  405.298
# After 392  training step(s), loss on training batch is  401.905
# After 415  training step(s), loss on training batch is  399.552
# After 438  training step(s), loss on training batch is  396.664
# After 461  training step(s), loss on training batch is  394.018
# rang 20 current test loss value on test set is  412.755
# After 484  training step(s), loss on training batch is  391.566
# After 507  training step(s), loss on training batch is  379.993
# After 530  training step(s), loss on training batch is  388.149
# After 553  training step(s), loss on training batch is  385.891
# After 576  training step(s), loss on training batch is  383.407
# rang 25 current test loss value on test set is  405.012
# After 599  training step(s), loss on training batch is  381.791
# After 622  training step(s), loss on training batch is  379.936
# After 645  training step(s), loss on training batch is  375.89
# After 668  training step(s), loss on training batch is  376.45
# After 691  training step(s), loss on training batch is  374.09
# rang 30 current test loss value on test set is  397.081
# After 714  training step(s), loss on training batch is  372.056
# After 737  training step(s), loss on training batch is  368.835
# After 760  training step(s), loss on training batch is  369.24
# After 783  training step(s), loss on training batch is  365.468
# After 806  training step(s), loss on training batch is  363.193
# rang 35 current test loss value on test set is  388.753
# After 829  training step(s), loss on training batch is  361.743
# After 852  training step(s), loss on training batch is  364.034
# After 875  training step(s), loss on training batch is  360.795
# After 898  training step(s), loss on training batch is  360.943
# After 921  training step(s), loss on training batch is  357.754
# rang 40 current test loss value on test set is  383.068
# After 944  training step(s), loss on training batch is  355.078
# After 967  training step(s), loss on training batch is  354.574
# After 990  training step(s), loss on training batch is  352.894
# After 1013  training step(s), loss on training batch is  351.058
# After 1036  training step(s), loss on training batch is  349.447
# rang 45 current test loss value on test set is  376.582
# After 1059  training step(s), loss on training batch is  347.389
# After 1082  training step(s), loss on training batch is  347.124
# After 1105  training step(s), loss on training batch is  345.327
# After 1128  training step(s), loss on training batch is  343.431
# After 1151  training step(s), loss on training batch is  342.582
# rang 50 current test loss value on test set is  371.444
# After 1174  training step(s), loss on training batch is  341.768
# After 1197  training step(s), loss on training batch is  339.958
# After 1220  training step(s), loss on training batch is  338.711
# After 1243  training step(s), loss on training batch is  337.827
# After 1266  training step(s), loss on training batch is  336.003
# rang 55 current test loss value on test set is  365.893
# After 1289  training step(s), loss on training batch is  334.781
# After 1312  training step(s), loss on training batch is  333.265
# After 1335  training step(s), loss on training batch is  332.679
# After 1358  training step(s), loss on training batch is  332.023
# After 1381  training step(s), loss on training batch is  330.41
# rang 60 current test loss value on test set is  361.189
# After 1404  training step(s), loss on training batch is  329.006
# After 1427  training step(s), loss on training batch is  327.732
# After 1450  training step(s), loss on training batch is  327.442
# After 1473  training step(s), loss on training batch is  326.371
# After 1496  training step(s), loss on training batch is  326.142
# rang 65 current test loss value on test set is  357.26
# After 1519  training step(s), loss on training batch is  324.117
# After 1542  training step(s), loss on training batch is  322.566
# After 1565  training step(s), loss on training batch is  323.258
# After 1588  training step(s), loss on training batch is  321.42
# After 1611  training step(s), loss on training batch is  321.714
# rang 70 current test loss value on test set is  355.028
# After 1634  training step(s), loss on training batch is  320.275
# After 1657  training step(s), loss on training batch is  318.389
# After 1680  training step(s), loss on training batch is  318.235
# After 1703  training step(s), loss on training batch is  317.159
# After 1726  training step(s), loss on training batch is  316.541
# rang 75 current test loss value on test set is  351.768
# After 1749  training step(s), loss on training batch is  316.169
# After 1772  training step(s), loss on training batch is  314.652
# After 1795  training step(s), loss on training batch is  314.002
# After 1818  training step(s), loss on training batch is  313.101
# After 1841  training step(s), loss on training batch is  311.536
# rang 80 current test loss value on test set is  347.353
# After 1864  training step(s), loss on training batch is  310.745
# After 1887  training step(s), loss on training batch is  309.849
# After 1910  training step(s), loss on training batch is  309.058
# After 1933  training step(s), loss on training batch is  308.448
# After 1956  training step(s), loss on training batch is  307.672
# rang 85 current test loss value on test set is  344.567
# After 1979  training step(s), loss on training batch is  307.378
# After 2002  training step(s), loss on training batch is  307.531
# After 2025  training step(s), loss on training batch is  305.56
# After 2048  training step(s), loss on training batch is  306.091
# After 2071  training step(s), loss on training batch is  304.659
# rang 90 current test loss value on test set is  345.233
# After 2094  training step(s), loss on training batch is  306.711
# After 2117  training step(s), loss on training batch is  303.064
# After 2140  training step(s), loss on training batch is  302.294
# After 2163  training step(s), loss on training batch is  303.353
# After 2186  training step(s), loss on training batch is  301.346
# rang 95 current test loss value on test set is  340.271
# After 2209  training step(s), loss on training batch is  300.774
# After 2232  training step(s), loss on training batch is  300.194
# After 2255  training step(s), loss on training batch is  299.103
# After 2278  training step(s), loss on training batch is  299.655
# After 2301  training step(s), loss on training batch is  298.83
# rang 100 current test loss value on test set is  339.308
# After 2324  training step(s), loss on training batch is  299.127
# After 2347  training step(s), loss on training batch is  296.897
# After 2370  training step(s), loss on training batch is  349.406
# After 2393  training step(s), loss on training batch is  322.044
# After 2416  training step(s), loss on training batch is  371.52
# rang 105 current test loss value on test set is  299.45
# After 2439  training step(s), loss on training batch is  251.296
# After 2462  training step(s), loss on training batch is  253.828
# After 2485  training step(s), loss on training batch is  270.928
# After 2508  training step(s), loss on training batch is  337.34
# After 2531  training step(s), loss on training batch is  272.661
# rang 110 current test loss value on test set is  345.994
# After 2554  training step(s), loss on training batch is  332.656
# After 2577  training step(s), loss on training batch is  292.433
# After 2600  training step(s), loss on training batch is  246.467
# After 2623  training step(s), loss on training batch is  300.871
# After 2646  training step(s), loss on training batch is  251.823
# rang 115 current test loss value on test set is  246.717
# After 2669  training step(s), loss on training batch is  242.044
# After 2692  training step(s), loss on training batch is  258.797
# After 2715  training step(s), loss on training batch is  242.016
# After 2738  training step(s), loss on training batch is  239.127
# After 2761  training step(s), loss on training batch is  237.591
# rang 120 current test loss value on test set is  243.154
# After 2784  training step(s), loss on training batch is  241.68
# After 2807  training step(s), loss on training batch is  239.053
# After 2830  training step(s), loss on training batch is  241.874
# After 2853  training step(s), loss on training batch is  250.415
# After 2876  training step(s), loss on training batch is  236.844
# rang 125 current test loss value on test set is  235.793
# After 2899  training step(s), loss on training batch is  237.041
# After 2922  training step(s), loss on training batch is  247.454
# After 2945  training step(s), loss on training batch is  238.71
# After 2968  training step(s), loss on training batch is  238.463
# After 2991  training step(s), loss on training batch is  253.194
# rang 130 current test loss value on test set is  253.45
# After 3014  training step(s), loss on training batch is  251.47
# After 3037  training step(s), loss on training batch is  237.212
# After 3060  training step(s), loss on training batch is  250.857
# After 3083  training step(s), loss on training batch is  240.572
# After 3106  training step(s), loss on training batch is  240.257
# rang 135 current test loss value on test set is  245.041
# After 3129  training step(s), loss on training batch is  245.394
# After 3152  training step(s), loss on training batch is  237.511
# After 3175  training step(s), loss on training batch is  243.738
# After 3198  training step(s), loss on training batch is  230.455
# After 3221  training step(s), loss on training batch is  244.446
# rang 140 current test loss value on test set is  226.589
# After 3244  training step(s), loss on training batch is  230.304
# After 3267  training step(s), loss on training batch is  244.387
# After 3290  training step(s), loss on training batch is  236.961
# After 3313  training step(s), loss on training batch is  228.239
# After 3336  training step(s), loss on training batch is  239.362
# rang 145 current test loss value on test set is  226.16
# After 3359  training step(s), loss on training batch is  228.631
# After 3382  training step(s), loss on training batch is  232.87
# After 3405  training step(s), loss on training batch is  240.547
# After 3428  training step(s), loss on training batch is  233.267
# After 3451  training step(s), loss on training batch is  227.04
# rang 150 current test loss value on test set is  241.973
# After 3474  training step(s), loss on training batch is  241.06
# After 3497  training step(s), loss on training batch is  228.322
# After 3520  training step(s), loss on training batch is  229.33
# After 3543  training step(s), loss on training batch is  227.399
# After 3566  training step(s), loss on training batch is  232.359
# rang 155 current test loss value on test set is  223.033
# After 3589  training step(s), loss on training batch is  224.983
# After 3612  training step(s), loss on training batch is  228.173
# After 3635  training step(s), loss on training batch is  225.438
# After 3658  training step(s), loss on training batch is  241.874
# After 3681  training step(s), loss on training batch is  224.754
# rang 160 current test loss value on test set is  241.837
# After 3704  training step(s), loss on training batch is  239.305
# After 3727  training step(s), loss on training batch is  224.663
# After 3750  training step(s), loss on training batch is  239.54
# After 3773  training step(s), loss on training batch is  224.603
# After 3796  training step(s), loss on training batch is  230.819
# rang 165 current test loss value on test set is  224.363
# After 3819  training step(s), loss on training batch is  224.352
# After 3842  training step(s), loss on training batch is  230.368
# After 3865  training step(s), loss on training batch is  226.283
# After 3888  training step(s), loss on training batch is  223.2
# After 3911  training step(s), loss on training batch is  223.072
# rang 170 current test loss value on test set is  228.69
# After 3934  training step(s), loss on training batch is  225.994
# After 3957  training step(s), loss on training batch is  223.884
# After 3980  training step(s), loss on training batch is  227.877
# After 4003  training step(s), loss on training batch is  223.893
# After 4026  training step(s), loss on training batch is  231.549
# rang 175 current test loss value on test set is  228.856
# After 4049  training step(s), loss on training batch is  225.651
# After 4072  training step(s), loss on training batch is  227.595
# After 4095  training step(s), loss on training batch is  231.931
# After 4118  training step(s), loss on training batch is  226.81
# After 4141  training step(s), loss on training batch is  228.635
# rang 180 current test loss value on test set is  239.682
# After 4164  training step(s), loss on training batch is  233.615
# After 4187  training step(s), loss on training batch is  230.802
# After 4210  training step(s), loss on training batch is  231.173
# After 4233  training step(s), loss on training batch is  230.05
# After 4256  training step(s), loss on training batch is  226.806
# rang 185 current test loss value on test set is  237.199
# After 4279  training step(s), loss on training batch is  230.134
# After 4302  training step(s), loss on training batch is  227.46
# After 4325  training step(s), loss on training batch is  226.581
# After 4348  training step(s), loss on training batch is  229.606
# After 4371  training step(s), loss on training batch is  228.739
# rang 190 current test loss value on test set is  234.077
# After 4394  training step(s), loss on training batch is  227.214
# After 4417  training step(s), loss on training batch is  227.442
# After 4440  training step(s), loss on training batch is  227.251
# After 4463  training step(s), loss on training batch is  227.026
# After 4486  training step(s), loss on training batch is  227.248
# rang 195 current test loss value on test set is  234.105
# After 4509  training step(s), loss on training batch is  225.805
# After 4532  training step(s), loss on training batch is  224.751
# After 4555  training step(s), loss on training batch is  223.921
# After 4578  training step(s), loss on training batch is  224.188
# After 4601  training step(s), loss on training batch is  224.695
# rang 200 current test loss value on test set is  233.67
# After 4624  training step(s), loss on training batch is  224.768
# After 4647  training step(s), loss on training batch is  223.642
# After 4670  training step(s), loss on training batch is  225.038
# After 4693  training step(s), loss on training batch is  221.536
# After 4716  training step(s), loss on training batch is  220.275
# rang 205 current test loss value on test set is  230.781
# After 4739  training step(s), loss on training batch is  219.882
# After 4762  training step(s), loss on training batch is  219.425
# After 4785  training step(s), loss on training batch is  218.363
# After 4808  training step(s), loss on training batch is  218.568
# After 4831  training step(s), loss on training batch is  217.174
# rang 210 current test loss value on test set is  228.747
# After 4854  training step(s), loss on training batch is  217.078
# After 4877  training step(s), loss on training batch is  216.726
# After 4900  training step(s), loss on training batch is  216.679
# After 4923  training step(s), loss on training batch is  216.684
# After 4946  training step(s), loss on training batch is  215.797
# rang 215 current test loss value on test set is  228.701
# After 4969  training step(s), loss on training batch is  215.354
# After 4992  training step(s), loss on training batch is  215.437
# After 5015  training step(s), loss on training batch is  214.056
# After 5038  training step(s), loss on training batch is  215.226
# After 5061  training step(s), loss on training batch is  214.605
# rang 220 current test loss value on test set is  228.231
# After 5084  training step(s), loss on training batch is  213.854
# After 5107  training step(s), loss on training batch is  213.343
# After 5130  training step(s), loss on training batch is  213.214
# After 5153  training step(s), loss on training batch is  213.215
# After 5176  training step(s), loss on training batch is  212.95
# rang 225 current test loss value on test set is  227.311
# After 5199  training step(s), loss on training batch is  212.157
# After 5222  training step(s), loss on training batch is  211.859
# After 5245  training step(s), loss on training batch is  211.854
# After 5268  training step(s), loss on training batch is  211.429
# After 5291  training step(s), loss on training batch is  211.889
# rang 230 current test loss value on test set is  226.711
# After 5314  training step(s), loss on training batch is  210.545
# After 5337  training step(s), loss on training batch is  210.525
# After 5360  training step(s), loss on training batch is  210.927
# After 5383  training step(s), loss on training batch is  210.522
# After 5406  training step(s), loss on training batch is  209.427
# rang 235 current test loss value on test set is  227.283
# After 5429  training step(s), loss on training batch is  210.066
# After 5452  training step(s), loss on training batch is  208.869
# After 5475  training step(s), loss on training batch is  208.7
# After 5498  training step(s), loss on training batch is  208.135
# After 5521  training step(s), loss on training batch is  207.683
# rang 240 current test loss value on test set is  227.467
# After 5544  training step(s), loss on training batch is  206.873
# After 5567  training step(s), loss on training batch is  206.204
# After 5590  training step(s), loss on training batch is  205.394
# After 5613  training step(s), loss on training batch is  204.595
# After 5636  training step(s), loss on training batch is  203.8
# rang 245 current test loss value on test set is  227.065
# After 5659  training step(s), loss on training batch is  203.574
# After 5682  training step(s), loss on training batch is  202.484
# After 5705  training step(s), loss on training batch is  202.201
# After 5728  training step(s), loss on training batch is  201.262
# After 5751  training step(s), loss on training batch is  200.971
# rang 250 current test loss value on test set is  225.911
# After 5774  training step(s), loss on training batch is  200.17
# After 5797  training step(s), loss on training batch is  199.943
# After 5820  training step(s), loss on training batch is  199.067
# After 5843  training step(s), loss on training batch is  198.157
# After 5866  training step(s), loss on training batch is  198.088
# rang 255 current test loss value on test set is  225.16
# After 5889  training step(s), loss on training batch is  197.556
# After 5912  training step(s), loss on training batch is  196.808
# After 5935  training step(s), loss on training batch is  196.352
# After 5958  training step(s), loss on training batch is  196.1
# After 5981  training step(s), loss on training batch is  195.221
# rang 260 current test loss value on test set is  224.274
# After 6004  training step(s), loss on training batch is  194.666
# After 6027  training step(s), loss on training batch is  193.99
# After 6050  training step(s), loss on training batch is  194.125
# After 6073  training step(s), loss on training batch is  193.186
# After 6096  training step(s), loss on training batch is  192.789
# rang 265 current test loss value on test set is  223.592
# After 6119  training step(s), loss on training batch is  192.229
# After 6142  training step(s), loss on training batch is  192.098
# After 6165  training step(s), loss on training batch is  191.222
# After 6188  training step(s), loss on training batch is  190.851
# After 6211  training step(s), loss on training batch is  190.805
# rang 270 current test loss value on test set is  222.824
# After 6234  training step(s), loss on training batch is  190.513
# After 6257  training step(s), loss on training batch is  190.008
# After 6280  training step(s), loss on training batch is  189.289
# After 6303  training step(s), loss on training batch is  189.019
# After 6326  training step(s), loss on training batch is  188.0
# rang 275 current test loss value on test set is  222.035
# After 6349  training step(s), loss on training batch is  187.712
# After 6372  training step(s), loss on training batch is  187.441
# After 6395  training step(s), loss on training batch is  186.165
# After 6418  training step(s), loss on training batch is  186.019
# After 6441  training step(s), loss on training batch is  185.542
# rang 280 current test loss value on test set is  221.223
# After 6464  training step(s), loss on training batch is  184.905
# After 6487  training step(s), loss on training batch is  184.299
# After 6510  training step(s), loss on training batch is  184.344
# After 6533  training step(s), loss on training batch is  183.833
# After 6556  training step(s), loss on training batch is  183.423
# rang 285 current test loss value on test set is  220.789
# After 6579  training step(s), loss on training batch is  183.061
# After 6602  training step(s), loss on training batch is  181.991
# After 6625  training step(s), loss on training batch is  182.24
# After 6648  training step(s), loss on training batch is  181.869
# After 6671  training step(s), loss on training batch is  181.198
# rang 290 current test loss value on test set is  220.524
# After 6694  training step(s), loss on training batch is  181.064
# After 6717  training step(s), loss on training batch is  180.273
# After 6740  training step(s), loss on training batch is  180.267
# After 6763  training step(s), loss on training batch is  180.172
# After 6786  training step(s), loss on training batch is  179.637
# rang 295 current test loss value on test set is  220.031
# After 6809  training step(s), loss on training batch is  179.057
# After 6832  training step(s), loss on training batch is  178.263
# After 6855  training step(s), loss on training batch is  178.299
# After 6878  training step(s), loss on training batch is  177.887
# After 6901  training step(s), loss on training batch is  177.436
# rang 300 current test loss value on test set is  219.594
# After 6924  training step(s), loss on training batch is  177.056
# After 6947  training step(s), loss on training batch is  176.714
# After 6970  training step(s), loss on training batch is  176.488
# After 6993  training step(s), loss on training batch is  176.043
# After 7016  training step(s), loss on training batch is  175.563
# rang 305 current test loss value on test set is  219.56
# After 7039  training step(s), loss on training batch is  175.476
# After 7062  training step(s), loss on training batch is  174.824
# After 7085  training step(s), loss on training batch is  174.28
# After 7108  training step(s), loss on training batch is  174.255
# After 7131  training step(s), loss on training batch is  173.932
# rang 310 current test loss value on test set is  218.953
# After 7154  training step(s), loss on training batch is  173.359
# After 7177  training step(s), loss on training batch is  172.964
# After 7200  training step(s), loss on training batch is  172.895
# After 7223  training step(s), loss on training batch is  172.31
# After 7246  training step(s), loss on training batch is  171.825
# rang 315 current test loss value on test set is  218.291
# After 7269  training step(s), loss on training batch is  171.289
# After 7292  training step(s), loss on training batch is  170.269
# After 7315  training step(s), loss on training batch is  170.252
# After 7338  training step(s), loss on training batch is  170.068
# After 7361  training step(s), loss on training batch is  169.17
# rang 320 current test loss value on test set is  217.685
# After 7384  training step(s), loss on training batch is  169.138
# After 7407  training step(s), loss on training batch is  169.075
# After 7430  training step(s), loss on training batch is  168.629
# After 7453  training step(s), loss on training batch is  168.061
# After 7476  training step(s), loss on training batch is  168.029
# rang 325 current test loss value on test set is  217.296
# After 7499  training step(s), loss on training batch is  167.5
# After 7522  training step(s), loss on training batch is  167.141
# After 7545  training step(s), loss on training batch is  166.891
# After 7568  training step(s), loss on training batch is  166.788
# After 7591  training step(s), loss on training batch is  166.414
# rang 330 current test loss value on test set is  217.065
# After 7614  training step(s), loss on training batch is  166.105
# After 7637  training step(s), loss on training batch is  165.293
# After 7660  training step(s), loss on training batch is  165.785
# After 7683  training step(s), loss on training batch is  165.185
# After 7706  training step(s), loss on training batch is  164.871
# rang 335 current test loss value on test set is  216.704
# After 7729  training step(s), loss on training batch is  164.641
# After 7752  training step(s), loss on training batch is  164.208
# After 7775  training step(s), loss on training batch is  164.245
# After 7798  training step(s), loss on training batch is  163.764
# After 7821  training step(s), loss on training batch is  163.551
# rang 340 current test loss value on test set is  216.392
# After 7844  training step(s), loss on training batch is  163.263
# After 7867  training step(s), loss on training batch is  163.11
# After 7890  training step(s), loss on training batch is  162.884
# After 7913  training step(s), loss on training batch is  162.618
# After 7936  training step(s), loss on training batch is  162.301
# rang 345 current test loss value on test set is  216.17
# After 7959  training step(s), loss on training batch is  162.413
# After 7982  training step(s), loss on training batch is  161.963
# After 8005  training step(s), loss on training batch is  161.867
# After 8028  training step(s), loss on training batch is  161.628
# After 8051  training step(s), loss on training batch is  161.565
# rang 350 current test loss value on test set is  215.987
# After 8074  training step(s), loss on training batch is  161.097
# After 8097  training step(s), loss on training batch is  161.043
# After 8120  training step(s), loss on training batch is  160.923
# After 8143  training step(s), loss on training batch is  160.738
# After 8166  training step(s), loss on training batch is  160.551
# rang 355 current test loss value on test set is  215.9
# After 8189  training step(s), loss on training batch is  160.317
# After 8212  training step(s), loss on training batch is  160.217
# After 8235  training step(s), loss on training batch is  160.083
# After 8258  training step(s), loss on training batch is  159.944
# After 8281  training step(s), loss on training batch is  159.651
# rang 360 current test loss value on test set is  215.697
# After 8304  training step(s), loss on training batch is  159.518
# After 8327  training step(s), loss on training batch is  159.629
# After 8350  training step(s), loss on training batch is  159.425
# After 8373  training step(s), loss on training batch is  159.233
# After 8396  training step(s), loss on training batch is  159.074
# rang 365 current test loss value on test set is  215.512
# After 8419  training step(s), loss on training batch is  158.73
# After 8442  training step(s), loss on training batch is  158.682
# After 8465  training step(s), loss on training batch is  158.577
# After 8488  training step(s), loss on training batch is  158.302
# After 8511  training step(s), loss on training batch is  158.397
# rang 370 current test loss value on test set is  215.344
# After 8534  training step(s), loss on training batch is  158.165
# After 8557  training step(s), loss on training batch is  157.99
# After 8580  training step(s), loss on training batch is  157.842
# After 8603  training step(s), loss on training batch is  157.787
# After 8626  training step(s), loss on training batch is  157.491
# rang 375 current test loss value on test set is  215.108
# After 8649  training step(s), loss on training batch is  157.527
# After 8672  training step(s), loss on training batch is  157.484
# After 8695  training step(s), loss on training batch is  157.216
# After 8718  training step(s), loss on training batch is  157.081
# After 8741  training step(s), loss on training batch is  157.041
# rang 380 current test loss value on test set is  214.933
# After 8764  training step(s), loss on training batch is  156.721
# After 8787  training step(s), loss on training batch is  156.747
# After 8810  training step(s), loss on training batch is  156.645
# After 8833  training step(s), loss on training batch is  156.536
# After 8856  training step(s), loss on training batch is  156.373
# rang 385 current test loss value on test set is  214.707
# After 8879  training step(s), loss on training batch is  156.27
# After 8902  training step(s), loss on training batch is  156.003
# After 8925  training step(s), loss on training batch is  156.191
# After 8948  training step(s), loss on training batch is  155.925
# After 8971  training step(s), loss on training batch is  155.831
# rang 390 current test loss value on test set is  214.687
# After 8994  training step(s), loss on training batch is  155.659
# After 9017  training step(s), loss on training batch is  155.634
# After 9040  training step(s), loss on training batch is  155.47
# After 9063  training step(s), loss on training batch is  155.68
# After 9086  training step(s), loss on training batch is  155.548
# rang 395 current test loss value on test set is  214.543
# After 9109  training step(s), loss on training batch is  155.331
# After 9132  training step(s), loss on training batch is  155.232
# After 9155  training step(s), loss on training batch is  155.176
# After 9178  training step(s), loss on training batch is  155.012
# After 9201  training step(s), loss on training batch is  154.889
# rang 400 current test loss value on test set is  214.374
# After 9224  training step(s), loss on training batch is  154.795
# After 9247  training step(s), loss on training batch is  154.706
# After 9270  training step(s), loss on training batch is  154.895
# After 9293  training step(s), loss on training batch is  154.746
# After 9316  training step(s), loss on training batch is  154.553
# rang 405 current test loss value on test set is  214.318
# After 9339  training step(s), loss on training batch is  154.542
# After 9362  training step(s), loss on training batch is  154.36
# After 9385  training step(s), loss on training batch is  154.339
# After 9408  training step(s), loss on training batch is  154.149
# After 9431  training step(s), loss on training batch is  154.039
# rang 410 current test loss value on test set is  214.275
# After 9454  training step(s), loss on training batch is  154.082
# After 9477  training step(s), loss on training batch is  153.884
# After 9500  training step(s), loss on training batch is  153.788
# After 9523  training step(s), loss on training batch is  153.799
# After 9546  training step(s), loss on training batch is  153.744
# rang 415 current test loss value on test set is  214.223
# After 9569  training step(s), loss on training batch is  153.618
# After 9592  training step(s), loss on training batch is  153.5
# After 9615  training step(s), loss on training batch is  153.622
# After 9638  training step(s), loss on training batch is  153.404
# After 9661  training step(s), loss on training batch is  153.277
# rang 420 current test loss value on test set is  214.135
# After 9684  training step(s), loss on training batch is  153.365
# After 9707  training step(s), loss on training batch is  153.165
# After 9730  training step(s), loss on training batch is  153.006
# After 9753  training step(s), loss on training batch is  152.949
# After 9776  training step(s), loss on training batch is  152.943
# rang 425 current test loss value on test set is  214.062
# After 9799  training step(s), loss on training batch is  153.023
# After 9822  training step(s), loss on training batch is  152.859
# After 9845  training step(s), loss on training batch is  152.844
# After 9868  training step(s), loss on training batch is  152.73
# After 9891  training step(s), loss on training batch is  152.651
# rang 430 current test loss value on test set is  214.054
# After 9914  training step(s), loss on training batch is  152.525
# After 9937  training step(s), loss on training batch is  152.619
# After 9960  training step(s), loss on training batch is  152.493
# After 9983  training step(s), loss on training batch is  152.273
# After 10006  training step(s), loss on training batch is  152.297
# rang 435 current test loss value on test set is  213.952
# After 10029  training step(s), loss on training batch is  152.158
# After 10052  training step(s), loss on training batch is  152.093
# After 10075  training step(s), loss on training batch is  152.122
# After 10098  training step(s), loss on training batch is  152.206
# After 10121  training step(s), loss on training batch is  152.041
# rang 440 current test loss value on test set is  213.87
# After 10144  training step(s), loss on training batch is  151.922
# After 10167  training step(s), loss on training batch is  151.914
# After 10190  training step(s), loss on training batch is  151.798
# After 10213  training step(s), loss on training batch is  151.756
# After 10236  training step(s), loss on training batch is  151.649
# rang 445 current test loss value on test set is  213.874
# After 10259  training step(s), loss on training batch is  151.622
# After 10282  training step(s), loss on training batch is  151.64
# After 10305  training step(s), loss on training batch is  151.488
# After 10328  training step(s), loss on training batch is  151.521
# After 10351  training step(s), loss on training batch is  151.607
# rang 450 current test loss value on test set is  213.811
# After 10374  training step(s), loss on training batch is  151.601
# After 10397  training step(s), loss on training batch is  151.486
# After 10420  training step(s), loss on training batch is  151.31
# After 10443  training step(s), loss on training batch is  151.352
# After 10466  training step(s), loss on training batch is  151.293
# rang 455 current test loss value on test set is  213.699
# After 10489  training step(s), loss on training batch is  151.155
# After 10512  training step(s), loss on training batch is  151.153
# After 10535  training step(s), loss on training batch is  151.131
# After 10558  training step(s), loss on training batch is  151.107
# After 10581  training step(s), loss on training batch is  150.96
# rang 460 current test loss value on test set is  213.688
# After 10604  training step(s), loss on training batch is  151.002
# After 10627  training step(s), loss on training batch is  150.863
# After 10650  training step(s), loss on training batch is  150.895
# After 10673  training step(s), loss on training batch is  150.915
# After 10696  training step(s), loss on training batch is  150.834
# rang 465 current test loss value on test set is  213.675
# After 10719  training step(s), loss on training batch is  150.765
# After 10742  training step(s), loss on training batch is  150.774
# After 10765  training step(s), loss on training batch is  150.658
# After 10788  training step(s), loss on training batch is  150.606
# After 10811  training step(s), loss on training batch is  150.622
# rang 470 current test loss value on test set is  213.664
# After 10834  training step(s), loss on training batch is  150.559
# After 10857  training step(s), loss on training batch is  150.473
# After 10880  training step(s), loss on training batch is  150.421
# After 10903  training step(s), loss on training batch is  150.458
# After 10926  training step(s), loss on training batch is  150.389
# rang 475 current test loss value on test set is  213.642
# After 10949  training step(s), loss on training batch is  150.383
# After 10972  training step(s), loss on training batch is  150.31
# After 10995  training step(s), loss on training batch is  150.255
# After 11018  training step(s), loss on training batch is  150.235
# After 11041  training step(s), loss on training batch is  150.243
# rang 480 current test loss value on test set is  213.615
# After 11064  training step(s), loss on training batch is  150.206
# After 11087  training step(s), loss on training batch is  150.137
# After 11110  training step(s), loss on training batch is  150.174
# After 11133  training step(s), loss on training batch is  150.059
# After 11156  training step(s), loss on training batch is  150.059
# rang 485 current test loss value on test set is  213.61
# After 11179  training step(s), loss on training batch is  149.989
# After 11202  training step(s), loss on training batch is  149.944
# After 11225  training step(s), loss on training batch is  149.91
# After 11248  training step(s), loss on training batch is  149.931
# After 11271  training step(s), loss on training batch is  149.852
# rang 490 current test loss value on test set is  213.567
# After 11294  training step(s), loss on training batch is  149.879
# After 11317  training step(s), loss on training batch is  149.847
# After 11340  training step(s), loss on training batch is  149.759
# After 11363  training step(s), loss on training batch is  149.781
# After 11386  training step(s), loss on training batch is  149.675
# rang 495 current test loss value on test set is  213.578
# After 11409  training step(s), loss on training batch is  149.672
# After 11432  training step(s), loss on training batch is  149.669
# After 11455  training step(s), loss on training batch is  149.615
# After 11478  training step(s), loss on training batch is  149.605
# After 11501  training step(s), loss on training batch is  149.602
# rang 500 current test loss value on test set is  213.593
# After 11524  training step(s), loss on training batch is  149.513
# After 11547  training step(s), loss on training batch is  149.53
# After 11570  training step(s), loss on training batch is  149.503
# After 11593  training step(s), loss on training batch is  149.439
# After 11616  training step(s), loss on training batch is  149.411
# rang 505 current test loss value on test set is  213.556
# After 11639  training step(s), loss on training batch is  149.417
# After 11662  training step(s), loss on training batch is  149.399
# After 11685  training step(s), loss on training batch is  149.339
# After 11708  training step(s), loss on training batch is  149.319
# After 11731  training step(s), loss on training batch is  149.281
# rang 510 current test loss value on test set is  213.547
# After 11754  training step(s), loss on training batch is  149.256
# After 11777  training step(s), loss on training batch is  149.218
# After 11800  training step(s), loss on training batch is  149.194
# After 11823  training step(s), loss on training batch is  149.157
# After 11846  training step(s), loss on training batch is  149.097
# rang 515 current test loss value on test set is  213.559
# After 11869  training step(s), loss on training batch is  149.043
# After 11892  training step(s), loss on training batch is  149.134
# After 11915  training step(s), loss on training batch is  149.024
# After 11938  training step(s), loss on training batch is  148.985
# After 11961  training step(s), loss on training batch is  148.963
# rang 520 current test loss value on test set is  213.547
# After 11984  training step(s), loss on training batch is  148.935
# After 12007  training step(s), loss on training batch is  148.961
# After 12030  training step(s), loss on training batch is  148.881
# After 12053  training step(s), loss on training batch is  148.859
# After 12076  training step(s), loss on training batch is  148.83
# rang 525 current test loss value on test set is  213.539
# After 12099  training step(s), loss on training batch is  148.791
# After 12122  training step(s), loss on training batch is  148.815
# After 12145  training step(s), loss on training batch is  148.795
# After 12168  training step(s), loss on training batch is  148.752
# After 12191  training step(s), loss on training batch is  148.733
# rang 530 current test loss value on test set is  213.553
# After 12214  training step(s), loss on training batch is  148.694
# After 12237  training step(s), loss on training batch is  148.751
# After 12260  training step(s), loss on training batch is  148.694
# After 12283  training step(s), loss on training batch is  148.633
# After 12306  training step(s), loss on training batch is  148.604
# rang 535 current test loss value on test set is  213.52
# After 12329  training step(s), loss on training batch is  148.563
# After 12352  training step(s), loss on training batch is  148.534
# After 12375  training step(s), loss on training batch is  148.484
# After 12398  training step(s), loss on training batch is  148.488
# After 12421  training step(s), loss on training batch is  148.459
# rang 540 current test loss value on test set is  213.529
# After 12444  training step(s), loss on training batch is  148.408
# After 12467  training step(s), loss on training batch is  148.413
# After 12490  training step(s), loss on training batch is  148.413
# After 12513  training step(s), loss on training batch is  148.364
# After 12536  training step(s), loss on training batch is  148.334
# rang 545 current test loss value on test set is  213.509
# After 12559  training step(s), loss on training batch is  148.303
# After 12582  training step(s), loss on training batch is  148.281
# After 12605  training step(s), loss on training batch is  148.242
# After 12628  training step(s), loss on training batch is  148.239
# After 12651  training step(s), loss on training batch is  148.219
# rang 550 current test loss value on test set is  213.528
# After 12674  training step(s), loss on training batch is  148.223
# After 12697  training step(s), loss on training batch is  148.204
# After 12720  training step(s), loss on training batch is  148.195
# After 12743  training step(s), loss on training batch is  148.163
# After 12766  training step(s), loss on training batch is  148.153
# rang 555 current test loss value on test set is  213.517
# After 12789  training step(s), loss on training batch is  148.141
# After 12812  training step(s), loss on training batch is  148.122
# After 12835  training step(s), loss on training batch is  148.106
# After 12858  training step(s), loss on training batch is  148.083
# After 12881  training step(s), loss on training batch is  148.062
# rang 560 current test loss value on test set is  213.517
# After 12904  training step(s), loss on training batch is  148.024
# After 12927  training step(s), loss on training batch is  148.003
# After 12950  training step(s), loss on training batch is  148.042
# After 12973  training step(s), loss on training batch is  147.995
# After 12996  training step(s), loss on training batch is  147.965
# rang 565 current test loss value on test set is  213.53
# After 13019  training step(s), loss on training batch is  147.938
# After 13042  training step(s), loss on training batch is  147.923
# After 13065  training step(s), loss on training batch is  147.927
# After 13088  training step(s), loss on training batch is  147.905
# After 13111  training step(s), loss on training batch is  147.885
# rang 570 current test loss value on test set is  213.525
# After 13134  training step(s), loss on training batch is  147.853
# After 13157  training step(s), loss on training batch is  147.865
# After 13180  training step(s), loss on training batch is  147.863
# After 13203  training step(s), loss on training batch is  147.834
# After 13226  training step(s), loss on training batch is  147.817
# rang 575 current test loss value on test set is  213.528
# After 13249  training step(s), loss on training batch is  147.795
# After 13272  training step(s), loss on training batch is  147.824
# After 13295  training step(s), loss on training batch is  147.793
# After 13318  training step(s), loss on training batch is  147.782
# After 13341  training step(s), loss on training batch is  147.751
# rang 580 current test loss value on test set is  213.527
# After 13364  training step(s), loss on training batch is  147.734
# After 13387  training step(s), loss on training batch is  147.713
# After 13410  training step(s), loss on training batch is  147.726
# After 13433  training step(s), loss on training batch is  147.702
# After 13456  training step(s), loss on training batch is  147.677
# rang 585 current test loss value on test set is  213.531
# After 13479  training step(s), loss on training batch is  147.698
# After 13502  training step(s), loss on training batch is  147.693
# After 13525  training step(s), loss on training batch is  147.663
# After 13548  training step(s), loss on training batch is  147.648
# After 13571  training step(s), loss on training batch is  147.628
# rang 590 current test loss value on test set is  213.521
# After 13594  training step(s), loss on training batch is  147.65
# After 13617  training step(s), loss on training batch is  147.613
# After 13640  training step(s), loss on training batch is  147.597
# After 13663  training step(s), loss on training batch is  147.588
# After 13686  training step(s), loss on training batch is  147.557
# rang 595 current test loss value on test set is  213.541
# After 13709  training step(s), loss on training batch is  147.574
# After 13732  training step(s), loss on training batch is  147.559
# After 13755  training step(s), loss on training batch is  147.542
# After 13778  training step(s), loss on training batch is  147.531
# After 13801  training step(s), loss on training batch is  147.537
# rang 600 current test loss value on test set is  213.527
# After 13824  training step(s), loss on training batch is  147.527
# After 13847  training step(s), loss on training batch is  147.509
# After 13870  training step(s), loss on training batch is  147.496
# After 13893  training step(s), loss on training batch is  147.484
# After 13916  training step(s), loss on training batch is  147.469
# rang 605 current test loss value on test set is  213.543
# After 13939  training step(s), loss on training batch is  147.47
# After 13962  training step(s), loss on training batch is  147.455
# After 13985  training step(s), loss on training batch is  147.442
# After 14008  training step(s), loss on training batch is  147.427
# After 14031  training step(s), loss on training batch is  147.417
# rang 610 current test loss value on test set is  213.541
# After 14054  training step(s), loss on training batch is  147.418
# After 14077  training step(s), loss on training batch is  147.397
# After 14100  training step(s), loss on training batch is  147.398
# After 14123  training step(s), loss on training batch is  147.385
# After 14146  training step(s), loss on training batch is  147.394
# rang 615 current test loss value on test set is  213.537
# After 14169  training step(s), loss on training batch is  147.388
# After 14192  training step(s), loss on training batch is  147.365
# After 14215  training step(s), loss on training batch is  147.349
# After 14238  training step(s), loss on training batch is  147.359
# After 14261  training step(s), loss on training batch is  147.35
# rang 620 current test loss value on test set is  213.545
# After 14284  training step(s), loss on training batch is  147.342
# After 14307  training step(s), loss on training batch is  147.316
# After 14330  training step(s), loss on training batch is  147.321
# After 14353  training step(s), loss on training batch is  147.311
# After 14376  training step(s), loss on training batch is  147.301
# rang 625 current test loss value on test set is  213.543
# After 14399  training step(s), loss on training batch is  147.294
# ...
# After 22978  training step(s), loss on training batch is  146.584
# After 23001  training step(s), loss on training batch is  146.584
# rang 1000 current test loss value on test set is  213.591
# After 23024  training step(s), loss on training batch is  146.584
# After 23047  training step(s), loss on training batch is  146.583
# After 23070  training step(s), loss on training batch is  146.583
# After 23093  training step(s), loss on training batch is  146.583
# After 23116  training step(s), loss on training batch is  146.583
# rang 1005 current test loss value on test set is  213.591
# After 23139  training step(s), loss on training batch is  146.583
# After 23162  training step(s), loss on training batch is  146.583
# After 23185  training step(s), loss on training batch is  146.583
# After 23208  training step(s), loss on training batch is  146.582
# After 23231  training step(s), loss on training batch is  146.582
# rang 1010 current test loss value on test set is  213.591
# After 23254  training step(s), loss on training batch is  146.582
# After 23277  training step(s), loss on training batch is  146.582
# After 23300  training step(s), loss on training batch is  146.582
# After 23323  training step(s), loss on training batch is  146.581
# After 23346  training step(s), loss on training batch is  146.581
# rang 1015 current test loss value on test set is  213.591
# After 23369  training step(s), loss on training batch is  146.581
# After 23392  training step(s), loss on training batch is  146.581
# After 23415  training step(s), loss on training batch is  146.581
# After 23438  training step(s), loss on training batch is  146.581
# After 23461  training step(s), loss on training batch is  146.581
# rang 1020 current test loss value on test set is  213.591
# After 23484  training step(s), loss on training batch is  146.58
# After 23507  training step(s), loss on training batch is  146.581
# After 23530  training step(s), loss on training batch is  146.581
# After 23553  training step(s), loss on training batch is  146.581
# After 23576  training step(s), loss on training batch is  146.58
# rang 1025 current test loss value on test set is  213.591
# After 23599  training step(s), loss on training batch is  146.58
# After 23622  training step(s), loss on training batch is  146.58
# After 23645  training step(s), loss on training batch is  146.58
# After 23668  training step(s), loss on training batch is  146.58
# After 23691  training step(s), loss on training batch is  146.579
# rang 1030 current test loss value on test set is  213.591
# After 23714  training step(s), loss on training batch is  146.579
# After 23737  training step(s), loss on training batch is  146.579
# After 23760  training step(s), loss on training batch is  146.579
# After 23783  training step(s), loss on training batch is  146.579
# After 23806  training step(s), loss on training batch is  146.579
# rang 1035 current test loss value on test set is  213.592
# After 23829  training step(s), loss on training batch is  146.579
# After 23852  training step(s), loss on training batch is  146.579
# After 23875  training step(s), loss on training batch is  146.578
# After 23898  training step(s), loss on training batch is  146.578
# After 23921  training step(s), loss on training batch is  146.578
# rang 1040 current test loss value on test set is  213.592
# After 23944  training step(s), loss on training batch is  146.578
# After 23967  training step(s), loss on training batch is  146.578
# After 23990  training step(s), loss on training batch is  146.578
# After 24013  training step(s), loss on training batch is  146.578
# After 24036  training step(s), loss on training batch is  146.578
# rang 1045 current test loss value on test set is  213.592
# After 24059  training step(s), loss on training batch is  146.578
# After 24082  training step(s), loss on training batch is  146.578
# After 24105  training step(s), loss on training batch is  146.578
# After 24128  training step(s), loss on training batch is  146.578
# After 24151  training step(s), loss on training batch is  146.577
# rang 1050 current test loss value on test set is  213.591
# After 24174  training step(s), loss on training batch is  146.577
# After 24197  training step(s), loss on training batch is  146.577
# After 24220  training step(s), loss on training batch is  146.577
# After 24243  training step(s), loss on training batch is  146.577
# After 24266  training step(s), loss on training batch is  146.577
# rang 1055 current test loss value on test set is  213.592
# After 24289  training step(s), loss on training batch is  146.577
# After 24312  training step(s), loss on training batch is  146.577
# After 24335  training step(s), loss on training batch is  146.577
# After 24358  training step(s), loss on training batch is  146.577
# After 24381  training step(s), loss on training batch is  146.576
# rang 1060 current test loss value on test set is  213.592
# After 24404  training step(s), loss on training batch is  146.576
# After 24427  training step(s), loss on training batch is  146.576
# After 24450  training step(s), loss on training batch is  146.576
# After 24473  training step(s), loss on training batch is  146.576
# After 24496  training step(s), loss on training batch is  146.576
# rang 1065 current test loss value on test set is  213.592
# After 24519  training step(s), loss on training batch is  146.576
# After 24542  training step(s), loss on training batch is  146.576
# After 24565  training step(s), loss on training batch is  146.576
# After 24588  training step(s), loss on training batch is  146.576
# After 24611  training step(s), loss on training batch is  146.575
# rang 1070 current test loss value on test set is  213.592
# After 24634  training step(s), loss on training batch is  146.575
# After 24657  training step(s), loss on training batch is  146.575
# After 24680  training step(s), loss on training batch is  146.575
# After 24703  training step(s), loss on training batch is  146.575
# After 24726  training step(s), loss on training batch is  146.575
# rang 1075 current test loss value on test set is  213.592
# After 24749  training step(s), loss on training batch is  146.575
# After 24772  training step(s), loss on training batch is  146.575
# After 24795  training step(s), loss on training batch is  146.575
# After 24818  training step(s), loss on training batch is  146.575
# After 24841  training step(s), loss on training batch is  146.575
# rang 1080 current test loss value on test set is  213.592
# After 24864  training step(s), loss on training batch is  146.575
# After 24887  training step(s), loss on training batch is  146.575
# After 24910  training step(s), loss on training batch is  146.575
# After 24933  training step(s), loss on training batch is  146.574
# After 24956  training step(s), loss on training batch is  146.574
# rang 1085 current test loss value on test set is  213.592
# After 24979  training step(s), loss on training batch is  146.574
# After 25002  training step(s), loss on training batch is  146.574
# After 25025  training step(s), loss on training batch is  146.574
# After 25048  training step(s), loss on training batch is  146.574
# After 25071  training step(s), loss on training batch is  146.574
# rang 1090 current test loss value on test set is  213.592
# After 25094  training step(s), loss on training batch is  146.574
# After 25117  training step(s), loss on training batch is  146.574
# After 25140  training step(s), loss on training batch is  146.574
# After 25163  training step(s), loss on training batch is  146.574
# After 25186  training step(s), loss on training batch is  146.574
# rang 1095 current test loss value on test set is  213.592
# After 25209  training step(s), loss on training batch is  146.574
# After 25232  training step(s), loss on training batch is  146.573
# After 25255  training step(s), loss on training batch is  146.574
# After 25278  training step(s), loss on training batch is  146.573
# After 25301  training step(s), loss on training batch is  146.573
# rang 1100 current test loss value on test set is  213.592
# After 25324  training step(s), loss on training batch is  146.573
# After 25347  training step(s), loss on training batch is  146.573
# After 25370  training step(s), loss on training batch is  146.573
# After 25393  training step(s), loss on training batch is  146.573
# After 25416  training step(s), loss on training batch is  146.573
# rang 1105 current test loss value on test set is  213.592
# After 25439  training step(s), loss on training batch is  146.573
# After 25462  training step(s), loss on training batch is  146.573
# After 25485  training step(s), loss on training batch is  146.573
# After 25508  training step(s), loss on training batch is  146.573
# After 25531  training step(s), loss on training batch is  146.573
# rang 1110 current test loss value on test set is  213.592
# After 25554  training step(s), loss on training batch is  146.573
# After 25577  training step(s), loss on training batch is  146.573
# After 25600  training step(s), loss on training batch is  146.573
# After 25623  training step(s), loss on training batch is  146.572
# After 25646  training step(s), loss on training batch is  146.573
# rang 1115 current test loss value on test set is  213.592
# After 25669  training step(s), loss on training batch is  146.572
# After 25692  training step(s), loss on training batch is  146.572
# After 25715  training step(s), loss on training batch is  146.572
# After 25738  training step(s), loss on training batch is  146.572
# After 25761  training step(s), loss on training batch is  146.572
# rang 1120 current test loss value on test set is  213.592
# After 25784  training step(s), loss on training batch is  146.572
# After 25807  training step(s), loss on training batch is  146.572
# After 25830  training step(s), loss on training batch is  146.572
# After 25853  training step(s), loss on training batch is  146.572
# After 25876  training step(s), loss on training batch is  146.572
# rang 1125 current test loss value on test set is  213.592
# After 25899  training step(s), loss on training batch is  146.572
# After 25922  training step(s), loss on training batch is  146.572
# After 25945  training step(s), loss on training batch is  146.572
# After 25968  training step(s), loss on training batch is  146.572
# After 25991  training step(s), loss on training batch is  146.572
# rang 1130 current test loss value on test set is  213.592
# After 26014  training step(s), loss on training batch is  146.572
# After 26037  training step(s), loss on training batch is  146.572
# After 26060  training step(s), loss on training batch is  146.572
# After 26083  training step(s), loss on training batch is  146.572
# After 26106  training step(s), loss on training batch is  146.572
# rang 1135 current test loss value on test set is  213.592
# After 26129  training step(s), loss on training batch is  146.571
# After 26152  training step(s), loss on training batch is  146.571
# After 26175  training step(s), loss on training batch is  146.571
# After 26198  training step(s), loss on training batch is  146.571
# After 26221  training step(s), loss on training batch is  146.571
# rang 1140 current test loss value on test set is  213.592
# After 26244  training step(s), loss on training batch is  146.571
# After 26267  training step(s), loss on training batch is  146.571
# After 26290  training step(s), loss on training batch is  146.571
# After 26313  training step(s), loss on training batch is  146.571
# After 26336  training step(s), loss on training batch is  146.571
# rang 1145 current test loss value on test set is  213.592
# After 26359  training step(s), loss on training batch is  146.571
# After 26382  training step(s), loss on training batch is  146.571
# After 26405  training step(s), loss on training batch is  146.571
# After 26428  training step(s), loss on training batch is  146.571
# After 26451  training step(s), loss on training batch is  146.571
# rang 1150 current test loss value on test set is  213.592
# After 26474  training step(s), loss on training batch is  146.571
# After 26497  training step(s), loss on training batch is  146.571
# After 26520  training step(s), loss on training batch is  146.571
# After 26543  training step(s), loss on training batch is  146.571
# After 26566  training step(s), loss on training batch is  146.571
# rang 1155 current test loss value on test set is  213.592
# After 26589  training step(s), loss on training batch is  146.571
# After 26612  training step(s), loss on training batch is  146.571
# After 26635  training step(s), loss on training batch is  146.571
# After 26658  training step(s), loss on training batch is  146.571
# After 26681  training step(s), loss on training batch is  146.57
# rang 1160 current test loss value on test set is  213.592
# After 26704  training step(s), loss on training batch is  146.57
# After 26727  training step(s), loss on training batch is  146.57
# After 26750  training step(s), loss on training batch is  146.57
# After 26773  training step(s), loss on training batch is  146.57
# After 26796  training step(s), loss on training batch is  146.57
# rang 1165 current test loss value on test set is  213.592
# After 26819  training step(s), loss on training batch is  146.57
# After 26842  training step(s), loss on training batch is  146.57
# After 26865  training step(s), loss on training batch is  146.57
# After 26888  training step(s), loss on training batch is  146.57
# After 26911  training step(s), loss on training batch is  146.57
# rang 1170 current test loss value on test set is  213.592
# After 26934  training step(s), loss on training batch is  146.57
# After 26957  training step(s), loss on training batch is  146.57
# After 26980  training step(s), loss on training batch is  146.57
# After 27003  training step(s), loss on training batch is  146.57
# After 27026  training step(s), loss on training batch is  146.57
# rang 1175 current test loss value on test set is  213.592
# After 27049  training step(s), loss on training batch is  146.57
# After 27072  training step(s), loss on training batch is  146.57
# After 27095  training step(s), loss on training batch is  146.57
# After 27118  training step(s), loss on training batch is  146.57
# After 27141  training step(s), loss on training batch is  146.57
# rang 1180 current test loss value on test set is  213.592
# After 27164  training step(s), loss on training batch is  146.57
# After 27187  training step(s), loss on training batch is  146.57
# After 27210  training step(s), loss on training batch is  146.57
# After 27233  training step(s), loss on training batch is  146.57
# After 27256  training step(s), loss on training batch is  146.57
# rang 1185 current test loss value on test set is  213.592
# After 27279  training step(s), loss on training batch is  146.57
# After 27302  training step(s), loss on training batch is  146.57
# After 27325  training step(s), loss on training batch is  146.57
# After 27348  training step(s), loss on training batch is  146.57
# After 27371  training step(s), loss on training batch is  146.57
# rang 1190 current test loss value on test set is  213.592
# After 27394  training step(s), loss on training batch is  146.569
# After 27417  training step(s), loss on training batch is  146.569
# After 27440  training step(s), loss on training batch is  146.569
# After 27463  training step(s), loss on training batch is  146.569
# After 27486  training step(s), loss on training batch is  146.569
# rang 1195 current test loss value on test set is  213.592
# After 27509  training step(s), loss on training batch is  146.569
# After 27532  training step(s), loss on training batch is  146.569
# After 27555  training step(s), loss on training batch is  146.569
# After 27578  training step(s), loss on training batch is  146.569
# After 27601  training step(s), loss on training batch is  146.569
# rang 1200 current test loss value on test set is  213.592
# After 27624  training step(s), loss on training batch is  146.569
# After 27647  training step(s), loss on training batch is  146.569
# After 27670  training step(s), loss on training batch is  146.569
# After 27693  training step(s), loss on training batch is  146.569
